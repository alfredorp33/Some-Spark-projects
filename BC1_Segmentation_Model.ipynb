# %%
spark.conf.set("spark.sql.shuffle.partitions", 1000)
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", -1)

# %%
from pyspark.ml.clustering import KMeans, KMeansModel, BisectingKMeans, BisectingKMeansModel
from pyspark.ml.feature import VectorAssembler, StandardScaler, PCA, PCAModel, ElementwiseProduct
from pyspark.ml import Pipeline, PipelineModel
from pyspark.sql.functions import col, sum, greatest, expr, count, countDistinct, max, min, variance, bround, avg, lit, udf
from pyspark.sql import Row
import pandas as pd
import matplotlib.pylab as plt
from pyspark.ml.linalg import Vectors
from pyspark.ml.linalg import SparseVector, DenseVector

#PARA EL TRATAMIENTO DE OUTLIERS
from pyspark.sql.functions import col, count, when
from functools import reduce
from operator import and_

# %% [markdown]
# ### Data Importation

# %%
dfEM=spark.read.parquet("/analytics/bc1_clustering/tables/dfEM")

# %%
#dfBufferOrig=spark.read.parquet("/analytics/bc1_clustering/tables/dfBufferAccYrGrpPart")
#dfBufferOrig=spark.read.parquet("/analytics/bc1_clustering/tables/dfBufferAccYrSubPart2")
# dfBufferOrig=spark.read.parquet("/analytics/bc1_clustering/tables/dfBufferAccYrGrp")
dfBufferOrig=spark.read.parquet("/analytics/bc1_clustering/tables/dfFinalMatrix11Dic")
# dfBufferOrig=dfBufferOrig.withColumnRenamed('','NULO')

# %%
# dfBufferOrig.persist()

nameList=dfBufferOrig.schema.names[1:]

len(nameList)
# Out:
# 727

# %%
dfBufferOrig.count()
# Out:
# 4166747

# %%
# [dfBuffer, dfTestBuffer] = dfBufferOrig.randomSplit([0.5, 0.5],666)

# %%
dfBuffer=dfBufferOrig.where(~dfBufferOrig['ACCOUNTPK'].cast('string').substr(-1,1).isin(['0','1','2','3','4'])).persist()

# %%
dfTestBuffer=dfBufferOrig.where(dfBufferOrig['ACCOUNTPK'].cast('string').substr(-1,1).isin(['0','1','2','3','4'])).persist()

# %%
#dfBuffer.write.parquet("/analytics/bc1_clustering/tables/dfTrainBufferBin")

# %%
#dfTestBuffer.write.parquet("/analytics/bc1_clustering/tables/dfTestBufferBin")

# %%
# dfBuffer=spark.read.parquet("/analytics/bc1_clustering/tables/dfTrainBufferBin")
# dfBuffer.persist()
# nameList=dfBuffer.schema.names[1:]

# %%
# dfTestBuffer=spark.read.parquet("/analytics/bc1_clustering/tables/dfTestBufferBin")
# dfTestBuffer.persist()
# Out:
# DataFrame[ACCOUNTPK: int, 1010540800: int, 1010540900: int, 1010541000: int, 1010541100: int, 1010541200: int, 1010541300: int, 1010541400: int, 1010541500: int, 1010541600: int, 1010541700: int, 1010541800: int, 1010541900: int, 1010542000: int, 1010542100: int, 1010690600: int, 1010690700: int, 1010690800: int, 1010690900: int, 1010751100: int, 1010751200: int, 1010751300: int, 1010751400: int, 1010760500: int, 1010760600: int, 1010760700: int, 1010760800: int, 1010781700: int, 1010781800: int, 1010781900: int, 1010782000: int, 1010790300: int, 1010790400: int, 1010790900: int, 1010791400: int, 1010791500: int, 1010792100: int, 1010792200: int, 1010792300: int, 1010792400: int, 1010792500: int, 1010792600: int, 1010792700: int, 1010792800: int, 1010792900: int, 1010793000: int, 1010793100: int, 1010793200: int, 1010793300: int, 1010793400: int, 1010793500: int, 1010793600: int, 1010793700: int, 1010793800: int, 1010810700: int, 1010810800: int, 1010810900: int, 1010811100: int, 1010811200: int, 1010811300: int, 1010811400: int, 1010811500: int, 1010830600: int, 1010830700: int, 1010830800: int, 1010830900: int, 1010831000: int, 1010852500: int, 1010852600: int, 1010852700: int, 1010852800: int, 1010852900: int, 1010853000: int, 1010853100: int, 1010853200: int, 1010853300: int, 1010853400: int, 1010853500: int, 1010853600: int, 1010853700: int, 1010853800: int, 1010853900: int, 1010854000: int, 1010854100: int, 1010854200: int, 1010862100: int, 1010862200: int, 1010862300: int, 1010862400: int, 1010862500: int, 1010862600: int, 1010862700: int, 1010862800: int, 1010862900: int, 1010863000: int, 1010863100: int, 1010863200: int, 1010863300: int, 1010863400: int, 1010863500: int, 1010863600: int, 1010863700: int, 1010863800: int, 1010863900: int, 1010864000: int, 1010864100: int, 1010864200: int, 1010864300: int, 1010864400: int, 1010870800: int, 1010870900: int, 1010871000: int, 1010871100: int, 1010871200: int, 1010871300: int, 1010871400: int, 1010871500: int, 1010871600: int, 1010895000: int, 1010895100: int, 1010895200: int, 1010895300: int, 1010902000: int, 1010902100: int, 1010902200: int, 1010902300: int, 1010902400: int, 1010902500: int, 1010902600: int, 1010902700: int, 1010902800: int, 1010902900: int, 1010903000: int, 1010903100: int, 1010903200: int, 1010903300: int, 1010903400: int, 1010903500: int, 1010920300: int, 1010920400: int, 1010920500: int, 1010920600: int, 1010920700: int, 1010920800: int, 1010920900: int, 1010921000: int, 1010921100: int, 1010921200: int, 1010960100: int, 1010960200: int, 1010960300: int, 1011480400: int, 1011480500: int, 1011480700: int, 1011480800: int, 1011480900: int, 1011491400: int, 1011491500: int, 1011491600: int, 1011491700: int, 1011491800: int, 1011491900: int, 1011510100: int, 1011510200: int, 1011510300: int, 1011520100: int, 1011520200: int, 1011520300: int, 1011520400: int, 1011520500: int, 1011520700: int, 1011520800: int, 1011521000: int, 1011521100: int, 1011530100: int, 1011530300: int, 1011530400: int, 1011530500: int, 1011530600: int, 1011530700: int, 1011540700: int, 1011540900: int, 1011541000: int, 1011541200: int, 1011541300: int, 1011550400: int, 1011550500: int, 1011550600: int, 1011550700: int, 1011551600: int, 1011551700: int, 1011551800: int, 1011552100: int, 1011552200: int, 1011552300: int, 1011552400: int, 1011552600: int, 1011552700: int, 1011561900: int, 1011562000: int, 1011562100: int, 1011562200: int, 1011580200: int, 1011580800: int, 1011580900: int, 1011581000: int, 1011581700: int, 1011581900: int, 1011582000: int, 1011582100: int, 1011582200: int, 1011582300: int, 1011582400: int, 1011582500: int, 1011590300: int, 1011590600: int, 1011590700: int, 1011590800: int, 1011590900: int, 1011591000: int, 1011600200: int, 1011600300: int, 1011610400: int, 1011610600: int, 1011610700: int, 1011610800: int, 1011610900: int, 1011611000: int, 1011611100: int, 1011620100: int, 1011620200: int, 1011620300: int, 1011620400: int, 1011620500: int, 1011630300: i ...

# %%
dfBuffer.count()
# Out:
# 2067865

# %%
dfTestBuffer.count()
# Out:
# 2098882

# %%
#dfTestBuffer.select(variance(dfTestBuffer.columns[2])).show()

# %%
#dfBufferOrig.select(dfBufferOrig['ACCOUNTPK'].cast('string').substr(-1,1).alias('caracter')).groupBy('caracter').count().show()

# %%
# dfTsys=spark.read.parquet("/analytics/bc1_clustering/tables/dfTsysAccYrOriginal")

# %%
# dfTsys.persist()
# Out:
# DataFrame[ACCOUNTPK: bigint, Emprestimo_Pessoal: bigint, Off_Us: bigint, Pagamento_de_Contas: bigint, Parcelamento_Fatura_Automatico: bigint, Parcelamento_Fatura_Facil: bigint, Saque_Parcelado: bigint, Saque_a_Vista: bigint]

# %%
dfTsys=dfBufferOrig.select('ACCOUNTPK','Emprestimo_Pessoal','Pagamento_de_Contas','Parcelamento_Fatura_Automatico','Parcelamento_Fatura_Facil','Saque_Parcelado','Saque_a_Vista','Overlimit')

# %% [markdown]
# ### Binary matrix creation

# %%
dfBufferBinary=dfBufferOrig.select([ i if i=='ACCOUNTPK' else when(col(i)!=0,1).otherwise(0).alias(i) for i in dfBufferOrig.columns])

# %%
dfBufferBinary.persist().count()

# %%
dfBufferBinary.write.parquet("/analytics/bc1_clustering/tables/dfBufferAccYrSubPartBin2")

# %%
# #TEST CONVERSOR A MATRIZ 0/1
# l = [('A',2.0,-3.0,0,-30.0),('B',0,-300.0,1,0),('C',7.0,0.0,2,-50.0),('D',12.0,-700.0,0,0)]
# rdd = sc.parallelize(l)
# dummy = rdd.map(lambda x: Row(ID=x[0], col1=float(x[1]),col2=float(x[2]),col3=float(x[3]),col4=float(x[4])))
# dummyDf = sqlContext.createDataFrame(dummy)
# dummyDf.show(5)
# dummyDf.select([ i if i=='ID' else when(col(i)!=0,1).otherwise(0).alias(i) for i in dummyDf.columns]).show()

# %% [markdown]
# ### Variable distribution histogram

# %%
#METODO HISTOGRAM DF
plt.clf()
#bins, counts = dummyDf.select('col1').rdd.flatMap(lambda x: x).histogram(20)
bins, counts = dfBuffer.select('CREDITLIMIT').rdd.flatMap(lambda x: x).histogram(20)
plt.hist(bins[:-1], bins=bins, weights=counts)

plt.show()
#.filter(col('101054')>0)

# %%
# #METODO hist DE PLT, parece que no funciona con grandes cantidades de datos
# plt.clf()
# #n, bins, patches = plt.hist(dummyDf.select('col4').collect(), 15, normed=1, facecolor='green', alpha=0.75)
# n, bins, patches = plt.hist(dfBuffer.select('1010540800').collect(), 15, normed=1, facecolor='green', alpha=0.75)
# plt.show()

# %% [markdown]
# ### Outlier treatment (for money value matrices)

# %%
len(nameList)

# %%
listaCols=[]
listaLimit=[]

for i in nameList:
    cuenta=dfBuffer.filter(col(i)>0).count()
    if cuenta>0:
        listaCols.append(i)
        Q1, Q3 = dfBuffer.filter(col(i)>0).approxQuantile(col=i,probabilities=[0.25,0.75],relativeError=0.01)
        IQR=(Q3-Q1)
        top_limit=Q3+9*IQR
        listaLimit.append(top_limit)

# %%
expr=reduce(and_, [col(c) < t for c, t in zip(listaCols, listaLimit)])

# %%
dfBufferOutlier=dfBuffer.where(expr)

# %%
dfBufferOutlier.persist().count()

# %%
dfBufferOutlier.write.parquet("/analytics/bc1_clustering/tables/dfBufferOutlier")

# %%
dfBufferOutlier=spark.read.parquet("/analytics/bc1_clustering/tables/dfBufferOutlier")

# %%
dfBufferOutlier.count()

# %% [markdown]
# ### Feature Assembler and Scaler

# %% [markdown]
# #### Binary matrices

# %%
dfBufferOutlier=dfBuffer
#dfBufferOutlier=dfTestBuffer.select(dfTestBuffer.columns[0:2400])

# %%
#continuous_feature_assembler= VectorAssembler(inputCols=dfTestBuffer.columns[0:2400], outputCol="features")
continuous_feature_assembler= VectorAssembler(inputCols=nameList, outputCol="features")

# %%
estimatorsKmeans = [continuous_feature_assembler]

featurePipeline = Pipeline(stages=estimatorsKmeans)

sparkFeaturePipelineModel = featurePipeline.fit(dfBufferOutlier)

# %%
dfBufferFeature=sparkFeaturePipelineModel.transform(dfBufferOutlier).persist()

# %%
dfBufferFeature.count()
# Out:
# 1331762

# %% [markdown]
# #### Money value matrices

# %%
#SI NO SE EJECUTA EL PROCESO DE OUTLIERS
dfBufferOutlier=dfBuffer
#dfBufferOutlier=dfTestBuffer.select(dfTestBuffer.columns[0:2400])

# %%
nameList=dfBuffer.schema.names[1:]

# %%
continuous_feature_assembler= VectorAssembler(inputCols=nameList, outputCol="unscaled_continuous_features")

# %%
continuous_feature_scaler = StandardScaler(inputCol="unscaled_continuous_features", outputCol="scaled_features",\
                                           withStd=True, withMean=True)

# %%
estimatorsKmeans = [continuous_feature_assembler, continuous_feature_scaler]

featurePipeline = Pipeline(stages=estimatorsKmeans)

sparkFeaturePipelineModel = featurePipeline.fit(dfBufferOutlier)

# %%
dfBufferScaled=sparkFeaturePipelineModel.transform(dfBufferOutlier).persist()

# %%
dfBufferScaled.count()
# Out:
# 2067865

# %%
dfBufferScaled.printSchema()
# Out:
# root
#  |-- ACCOUNTPK: long (nullable = true)
#  |-- BALANCE: double (nullable = true)
#  |-- INSTALMENTBALANCEFOROVLMCHECK: double (nullable = true)
#  |-- CREDITLIMIT: double (nullable = true)
#  |-- LimitUse: double (nullable = true)
#  |-- LimitOffUs: double (nullable = true)
#  |-- LimitPersLoan: double (nullable = true)
#  |-- LimitCashOut: double (nullable = true)
#  |-- CLOSING_BALANCE: double (nullable = true)
#  |-- INSTALLMENTSOFFERS: long (nullable = true)
#  |-- Emprestimo_Pessoal: long (nullable = true)
#  |-- Pagamento_de_Contas: long (nullable = true)
#  |-- Parcelamento_Fatura_Automatico: long (nullable = true)
#  |-- Parcelamento_Fatura_Facil: long (nullable = true)
#  |-- Saque_Parcelado: long (nullable = true)
#  |-- Saque_a_Vista: long (nullable = true)
#  |-- Overlimit: long (nullable = true)
#  |-- Overlimit_Auth: integer (nullable = true)
#  |-- NULO: double (nullable = true)
#  |-- 0742: double (nullable = true)
#  |-- 0763: double (nullable = true)
#  |-- 0780: double (nullable = true)
#  |-- 1520: double (nullable = true)
#  |-- 1711: double (nullable = true)
#  |-- 1731: double (nullable = true)
#  |-- 1740: double (nullable = true)
#  |-- 1750: double (nullable = true)
#  |-- 1761: double (nullable = true)
#  |-- 1771: double (nullable = true)
#  |-- 1799: double (nullable = true)
#  |-- 2741: double (nullable = true)
#  |-- 2791: double (nullable = true)
#  |-- 2842: double (nullable = true)
#  |-- 3000: double (nullable = true)
#  |-- 3001: double (nullable = true)
#  |-- 3005: double (nullable = true)
#  |-- 3007: double (nullable = true)
#  |-- 3008: double (nullable = true)
#  |-- 3009: double (nullable = true)
#  |-- 3010: double (nullable = true)
#  |-- 3011: double (nullable = true)
#  |-- 3012: double (nullable = true)
#  |-- 3013: double (nullable = true)
#  |-- 3014: double (nullable = true)
#  |-- 3015: double (nullable = true)
#  |-- 3016: double (nullable = true)
#  |-- 3017: double (nullable = true)
#  |-- 3018: double (nullable = true)
#  |-- 3020: double (nullable = true)
#  |-- 3025: double (nullable = true)
#  |-- 3026: double (nullable = true)
#  |-- 3028: double (nullable = true)
#  |-- 3029: double (nullable = true)
#  |-- 3030: double (nullable = true)
#  |-- 3034: double (nullable = true)
#  |-- 3035: double (nullable = true)
#  |-- 3039: double (nullable = true)
#  |-- 3042: double (nullable = true)
#  |-- 3043: double (nullable = true)
#  |-- 3047: double (nullable = true)
#  |-- 3048: double (nullable = true)
#  |-- 3051: double (nullable = true)
#  |-- 3052: double (nullable = true)
#  |-- 3056: double (nullable = true)
#  |-- 3057: double (nullable = true)
#  |-- 3058: double (nullable = true)
#  |-- 3066: double (nullable = true)
#  |-- 3069: double (nullable = true)
#  |-- 3076: double (nullable = true)
#  |-- 3077: double (nullable = true)
#  |-- 3079: double (nullable = true)
#  |-- 3082: double (nullable = true)
#  |-- 3088: double (nullable = true)
#  |-- 3098: double (nullable = true)
#  |-- 3102: double (nullable = true)
#  |-- 3127: double (nullable = true)
#  |-- 3132: double (nullable = true)
#  |-- 3136: double (nullable = true)
#  |-- 3161: double (nullable = true)
#  |-- 3171: double (nullable = true)
#  |-- 3174: double (nullable = true)
#  |-- 3180: double (nullable = true)
#  |-- 3182: double (nullable = true)
#  |-- 3187: double (nullable = true)
#  |-- 3206: double (nullable = true)
#  |-- 3211: double (nullable = true)
#  |-- 3217: double (nullable = true)
#  |-- 3219: double (nullable = true)
#  |-- 3221: double (nullable = true)
#  |-- 3236: double (nullable = true)
#  |-- 3239: double (nullable = true)
#  |-- 3245: double (nullable = true)
#  |-- 3246: double (nullable = true)
#  |-- 3247: double (nullable = true)
#  |-- 3248: double (nullable = true)
#  |-- 3256: double (nullable = true)
#  |-- 3260: double (nullable = true)
#  |-- 3261: double (nullable = true)
#  |-- 3294: double (nullable = true)
#  |-- 3296: double (nullable = true)
#  |-- 3351: double (nullable = true)
#  |-- 3355: double (nullable = true)
#  |-- 3357: double (nullable = true)
#  |-- 3359: double (nullable = true)
#  |-- 3364: double (nullable = true)
#  |-- 3366: double (nullable = true)
#  |-- 3374: double (nullable = true)
#  |-- 3381: double (nullable = true)
#  |-- 3387: double (nullable = true)
#  |-- 3389: double (nullable = true)
#  |-- 3390: double (nullable = true)
#  |-- 3393: double (nullable = true)
#  |-- 3395: double (nullable = true)
#  |-- 3405: double (nullable = true)
#  |-- 3441: double (nullable = true)
#  |-- 3501: double (nullable = true)
#  |-- 3502: double (nullable = true)
#  |-- 3503: double (nullable = true)
#  |-- 3504: double (nullable = true)
#  |-- 3505: double (nullable = true)
#  |-- 3506: double (nullable = true)
#  |-- 3508: double (nullable = true)
#  |-- 3509: double (nullable = true)
#  |-- 3510: double (nullable = true)
#  |-- 3512: double (nullable = true)
#  |-- 3513: double (nullable = true)
#  |-- 3515: double (nullable = true)
#  |-- 3516: double (nullable = true)
#  |-- 3517: double (nullable = true)
#  |-- 3520: double (nullable = true)
#  |-- 3528: double (nullable = true)
#  |-- 3530: double (nullable = true)
#  |-- 3533: double (nullable = true)
#  |-- 3535: double (nullable = true)
#  |-- 3543: double (nullable = true)
#  |-- 3548: double (nullable = true)
#  |-- 3549: double (nullable = true)
#  |-- 3553: double (nullable = true)
#  |-- 3555: double (nullable = true)
#  |-- 3562: double (nullable = true)
#  |-- 3563: double (nullable = true)
#  |-- 3567: double (nullable = true)
#  |-- 3579: double (nullable = true)
#  |-- 3581: double (nullable = true)
#  |-- 3583: double (nullable = true)
#  |-- 3584: double (nullable = true)
#  |-- 3586: double (nullable = true)
#  |-- 3590: double (nullable = true)
#  |-- 3591: double (nullable = true)
#  |-- 3596: double (nullable = true)
#  |-- 3602: double (nullable = true)
#  |-- 3604: double (nullable = true)
#  |-- 3607: double (nullable = true)
#  |-- 3608: double (nullable = true)
#  |-- 3612: double (nullable = true)
#  |-- 3615: double (nullable = true)
#  |-- 3617: double (nullable = true)
#  |-- 3621: double (nullable = true)
#  |-- 3628: double (nullable = true)
#  |-- 3629: double (nullable = true)
#  |-- 3631: double (nullable = true)
#  |-- 3637: double (nullable = true)
#  |-- 3638: double (nullable = true)
#  |-- 3640: double (nullable = true)
#  |-- 3641: double (nullable = true)
#  |-- 3642: double (nullable = true)
#  |-- 3644: double (nullable = true)
#  |-- 3649: double (nullable = true)
#  |-- 3650: double (nullable = true)
#  |-- 3654: double (nullable = true)
#  |-- 3656: double (nullable = true)
#  |-- 3660: double (nullable = true)
#  |-- 3662: double (nullable = true)
#  |-- 3665: double (nullable = true)
#  |-- 3667: double (nullable = true)
#  |-- 3668: double (nullable = true)
#  |-- 3672: double (nullable = true)
#  |-- 3676: double (nullable = true)
#  |-- 3680: double (nullable = true)
#  |-- 3687: double (nullable = true)
#  |-- 3690: double (nullable = true)
#  |-- 3692: double (nullable = true)
#  |-- 3693: double (nullable = true)
#  |-- 3695: double (nullable = true)
#  |-- 3700: double (nullable = true)
#  |-- 3703: double (nullable = true)
#  |-- 3709: double (nullable = true)
#  |-- 3715: double (nullable = true)
#  |-- 3719: double (nullable = true)
#  |-- 3721: double (nullable = true)
#  |-- 3722: double (nullable = true)
#  |-- 3726: double (nullable = true)
#  |-- 3728: double (nullable = true)
#  |-- 3730: double (nullable = true)
#  |-- 3731: double (nullable = true)
#  |-- 3737: double (nullable = true)
#  |-- 3742: double (nullable = true)
#  |-- 3750: double (nullable = true)
#  |-- 3751: double (nullable = true)
#  |-- 3765: double (nullable = true)
#  |-- 3769: double (nullable = true)
#  |-- 3771: double (nullable = true)
#  |-- 3773: double (nullable = true)
#  |-- 3774: double (nullable = true)
#  |-- 3778: double (nullable = true)
#  |-- 3779: double (nullable = true)
#  |-- 3780: double (nullable = true)
#  |-- 3782: double (nullable = true)
#  |-- 3792: double (nullable = true)
#  |-- 3793: double (nullable = true)
#  |-- 3795: double (nullable = true)
#  |-- 3808: double (nullable = true)
#  |-- 3811: double (nullable = true)
#  |-- 3812: double (nullable = true)
#  |-- 3813: double (nullable = true)
#  |-- 3814: double (nullable = true)
#  |-- 3816: double (nullable = true)
#  |-- 3824: double (nullable = true)
#  |-- 3825: double (nullable = true)
#  |-- 4011: double (nullable = true)
#  |-- 4111: double (nullable = true)
#  |-- 4112: double (nullable = true)
#  |-- 4119: double (nullable = true)
#  |-- 4121: double (nullable = true)
#  |-- 4131: double (nullable = true)
#  |-- 4214: double (nullable = true)
#  |-- 4215: double (nullable = true)
#  |-- 4225: double (nullable = true)
#  |-- 4411: double (nullable = true)
#  |-- 4457: double (nullable = true)
#  |-- 4468: double (nullable = true)
#  |-- 4511: double (nullable = true)
#  |-- 4582: double (nullable = true)
#  |-- 4722: double (nullable = true)
#  |-- 4723: double (nullable = true)
#  |-- 4784: double (nullable = true)
#  |-- 4789: double (nullable = true)
#  |-- 4812: double (nullable = true)
#  |-- 4813: double (nullable = true)
#  |-- 4814: double (nullable = true)
#  |-- 4816: double (nullable = true)
#  |-- 4821: double (nullable = true)
#  |-- 4829: double (nullable = true)
#  |-- 4899: double (nullable = true)
#  |-- 4900: double (nullable = true)
#  |-- 5013: double (nullable = true)
#  |-- 5021: double (nullable = true)
#  |-- 5039: double (nullable = true)
#  |-- 5044: double (nullable = true)
#  |-- 5045: double (nullable = true)
#  |-- 5046: double (nullable = true)
#  |-- 5047: double (nullable = true)
#  |-- 5051: double (nullable = true)
#  |-- 5065: double (nullable = true)
#  |-- 5072: double (nullable = true)
#  |-- 5074: double (nullable = true)
#  |-- 5085: double (nullable = true)
#  |-- 5094: double (nullable = true)
#  |-- 5099: double (nullable = true)
#  |-- 5111: double (nullable = true)
#  |-- 5122: double (nullable = true)
#  |-- 5131: double (nullable = true)
#  |-- 5137: double (nullable = true)
#  |-- 5139: double (nullable = true)
#  |-- 5169: double (nullable = true)
#  |-- 5172: double (nullable = true)
#  |-- 5192: double (nullable = true)
#  |-- 5193: double (nullable = true)
#  |-- 5198: double (nullable = true)
#  |-- 5199: double (nullable = true)
#  |-- 5200: double (nullable = true)
#  |-- 5211: double (nullable = true)
#  |-- 5231: double (nullable = true)
#  |-- 5251: double (nullable = true)
#  |-- 5261: double (nullable = true)
#  |-- 5271: double (nullable = true)
#  |-- 5300: double (nullable = true)
#  |-- 5309: double (nullable = true)
#  |-- 5310: double (nullable = true)
#  |-- 5311: double (nullable = true)
#  |-- 5331: double (nullable = true)
#  |-- 5399: double (nullable = true)
#  |-- 5411: double (nullable = true)
#  |-- 5422: double (nullable = true)
#  |-- 5441: double (nullable = true)
#  |-- 5451: double (nullable = true)
#  |-- 5462: double (nullable = true)
#  |-- 5499: double (nullable = true)
#  |-- 5511: double (nullable = true)
#  |-- 5521: double (nullable = true)
#  |-- 5531: double (nullable = true)
#  |-- 5532: double (nullable = true)
#  |-- 5533: double (nullable = true)
#  |-- 5541: double (nullable = true)
#  |-- 5542: double (nullable = true)
#  |-- 5551: double (nullable = true)
#  |-- 5561: double (nullable = true)
#  |-- 5571: double (nullable = true)
#  |-- 5592: double (nullable = true)
#  |-- 5598: double (nullable = true)
#  |-- 5599: double (nullable = true)
#  |-- 5611: double (nullable = true)
#  |-- 5621: double (nullable = true)
#  |-- 5631: double (nullable = true)
#  |-- 5641: double (nullable = true)
#  |-- 5651: double (nullable = true)
#  |-- 5655: double (nullable = true)
#  |-- 5661: double (nullable = true)
#  |-- 5681: double (nullable = true)
#  |-- 5691: double (nullable = true)
#  |-- 5697: double (nullable = true)
#  |-- 5698: double (nullable = true)
#  |-- 5699: double (nullable = true)
#  |-- 5712: double (nullable = true)
#  |-- 5713: double (nullable = true)
#  |-- 5714: double (nullable = true)
#  |-- 5718: double (nullable = true)
#  |-- 5719: double (nullable = true)
#  |-- 5722: double (nullable = true)
#  |-- 5732: double (nullable = true)
#  |-- 5733: double (nullable = true)
#  |-- 5734: double (nullable = true)
#  |-- 5735: double (nullable = true)
#  |-- 5811: double (nullable = true)
#  |-- 5812: double (nullable = true)
#  |-- 5813: double (nullable = true)
#  |-- 5814: double (nullable = true)
#  |-- 5815: double (nullable = true)
#  |-- 5816: double (nullable = true)
#  |-- 5817: double (nullable = true)
#  |-- 5818: double (nullable = true)
#  |-- 5912: double (nullable = true)
#  |-- 5921: double (nullable = true)
#  |-- 5931: double (nullable = true)
#  |-- 5932: double (nullable = true)
#  |-- 5933: double (nullable = true)
#  |-- 5935: double (nullable = true)
#  |-- 5937: double (nullable = true)
#  |-- 5940: double (nullable = true)
#  |-- 5941: double (nullable = true)
#  |-- 5942: double (nullable = true)
#  |-- 5943: double (nullable = true)
#  |-- 5944: double (nullable = true)
#  |-- 5945: double (nullable = true)
#  |-- 5946: double (nullable = true)
#  |-- 5947: double (nullable = true)
#  |-- 5948: double (nullable = true)
#  |-- 5949: double (nullable = true)
#  |-- 5950: double (nullable = true)
#  |-- 5960: double (nullable = true)
#  |-- 5962: double (nullable = true)
#  |-- 5963: double (nullable = true)
#  |-- 5964: double (nullable = true)
#  |-- 5965: double (nullable = true)
#  |-- 5966: double (nullable = true)
#  |-- 5967: double (nullable = true)
#  |-- 5968: double (nullable = true)
#  |-- 5969: double (nullable = true)
#  |-- 5970: double (nullable = true)
#  |-- 5971: double (nullable = true)
#  |-- 5972: double (nullable = true)
#  |-- 5973: double (nullable = true)
#  |-- 5975: double (nullable = true)
#  |-- 5976: double (nullable = true)
#  |-- 5977: double (nullable = true)
#  |-- 5978: double (nullable = true)
#  |-- 5983: double (nullable = true)
#  |-- 5992: double (nullable = true)
#  |-- 5993: double (nullable = true)
#  |-- 5994: double (nullable = true)
#  |-- 5995: double (nullable = true)
#  |-- 5996: double (nullable = true)
#  |-- 5997: double (nullable = true)
#  |-- 5998: double (nullable = true)
#  |-- 5999: double (nullable = true)
#  |-- 6012: double (nullable = true)
#  |-- 6051: double (nullable = true)
#  |-- 6211: double (nullable = true)
#  |-- 6300: double (nullable = true)
#  |-- 6513: double (nullable = true)
#  |-- 6540: double (nullable = true)
#  |-- 7011: double (nullable = true)
#  |-- 7012: double (nullable = true)
#  |-- 7032: double (nullable = true)
#  |-- 7033: double (nullable = true)
#  |-- 7210: double (nullable = true)
#  |-- 7211: double (nullable = true)
#  |-- 7216: double (nullable = true)
#  |-- 7217: double (nullable = true)
#  |-- 7221: double (nullable = true)
#  |-- 7230: double (nullable = true)
#  |-- 7251: double (nullable = true)
#  |-- 7261: double (nullable = true)
#  |-- 7273: double (nullable = true)
#  |-- 7276: double (nullable = true)
#  |-- 7277: double (nullable = true)
#  |-- 7278: double (nullable = true)
#  |-- 7296: double (nullable = true)
#  |-- 7297: double (nullable = true)
#  |-- 7298: double (nullable = true)
#  |-- 7299: double (nullable = true)
#  |-- 7311: double (nullable = true)
#  |-- 7321: double (nullable = true)
#  |-- 7333: double (nullable = true)
#  |-- 7338: double (nullable = true)
#  |-- 7339: double (nullable = true)
#  |-- 7342: double (nullable = true)
#  |-- 7349: double (nullable = true)
#  |-- 7361: double (nullable = true)
#  |-- 7372: double (nullable = true)
#  |-- 7375: double (nullable = true)
#  |-- 7379: double (nullable = true)
#  |-- 7392: double (nullable = true)
#  |-- 7393: double (nullable = true)
#  |-- 7394: double (nullable = true)
#  |-- 7395: double (nullable = true)
#  |-- 7399: double (nullable = true)
#  |-- 7512: double (nullable = true)
#  |-- 7513: double (nullable = true)
#  |-- 7519: double (nullable = true)
#  |-- 7523: double (nullable = true)
#  |-- 7531: double (nullable = true)
#  |-- 7534: double (nullable = true)
#  |-- 7535: double (nullable = true)
#  |-- 7538: double (nullable = true)
#  |-- 7542: double (nullable = true)
#  |-- 7549: double (nullable = true)
#  |-- 7622: double (nullable = true)
#  |-- 7623: double (nullable = true)
#  |-- 7629: double (nullable = true)
#  |-- 7631: double (nullable = true)
#  |-- 7641: double (nullable = true)
#  |-- 7692: double (nullable = true)
#  |-- 7699: double (nullable = true)
#  |-- 7829: double (nullable = true)
#  |-- 7832: double (nullable = true)
#  |-- 7841: double (nullable = true)
#  |-- 7911: double (nullable = true)
#  |-- 7922: double (nullable = true)
#  |-- 7929: double (nullable = true)
#  |-- 7932: double (nullable = true)
#  |-- 7933: double (nullable = true)
#  |-- 7941: double (nullable = true)
#  |-- 7991: double (nullable = true)
#  |-- 7992: double (nullable = true)
#  |-- 7993: double (nullable = true)
#  |-- 7994: double (nullable = true)
#  |-- 7995: double (nullable = true)
#  |-- 7996: double (nullable = true)
#  |-- 7997: double (nullable = true)
#  |-- 7998: double (nullable = true)
#  |-- 7999: double (nullable = true)
#  |-- 8011: double (nullable = true)
#  |-- 8021: double (nullable = true)
#  |-- 8031: double (nullable = true)
#  |-- 8041: double (nullable = true)
#  |-- 8042: double (nullable = true)
#  |-- 8043: double (nullable = true)
#  |-- 8049: double (nullable = true)
#  |-- 8050: double (nullable = true)
#  |-- 8062: double (nullable = true)
#  |-- 8071: double (nullable = true)
#  |-- 8099: double (nullable = true)
#  |-- 8111: double (nullable = true)
#  |-- 8211: double (nullable = true)
#  |-- 8220: double (nullable = true)
#  |-- 8241: double (nullable = true)
#  |-- 8242: double (nullable = true)
#  |-- 8244: double (nullable = true)
#  |-- 8249: double (nullable = true)
#  |-- 8299: double (nullable = true)
#  |-- 8351: double (nullable = true)
#  |-- 8398: double (nullable = true)
#  |-- 8641: double (nullable = true)
#  |-- 8651: double (nullable = true)
#  |-- 8661: double (nullable = true)
#  |-- 8675: double (nullable = true)
#  |-- 8699: double (nullable = true)
#  |-- 8734: double (nullable = true)
#  |-- 8911: double (nullable = true)
#  |-- 8931: double (nullable = true)
#  |-- 8999: double (nullable = true)
#  |-- 9211: double (nullable = true)
#  |-- 9222: double (nullable = true)
#  |-- 9311: double (nullable = true)
#  |-- 9399: double (nullable = true)
#  |-- 9402: double (nullable = true)
#  |-- 9405: double (nullable = true)
#  |-- 101054: double (nullable = true)
#  |-- 101069: double (nullable = true)
#  |-- 101075: double (nullable = true)
#  |-- 101076: double (nullable = true)
#  |-- 101078: double (nullable = true)
#  |-- 101079: double (nullable = true)
#  |-- 101081: double (nullable = true)
#  |-- 101083: double (nullable = true)
#  |-- 101085: double (nullable = true)
#  |-- 101086: double (nullable = true)
#  |-- 101087: double (nullable = true)
#  |-- 101089: double (nullable = true)
#  |-- 101090: double (nullable = true)
#  |-- 101092: double (nullable = true)
#  |-- 101096: double (nullable = true)
#  |-- 101148: double (nullable = true)
#  |-- 101149: double (nullable = true)
#  |-- 101151: double (nullable = true)
#  |-- 101152: double (nullable = true)
#  |-- 101153: double (nullable = true)
#  |-- 101154: double (nullable = true)
#  |-- 101155: double (nullable = true)
#  |-- 101156: double (nullable = true)
#  |-- 101158: double (nullable = true)
#  |-- 101159: double (nullable = true)
#  |-- 101160: double (nullable = true)
#  |-- 101161: double (nullable = true)
#  |-- 101162: double (nullable = true)
#  |-- 101163: double (nullable = true)
#  |-- 101164: double (nullable = true)
#  |-- 101165: double (nullable = true)
#  |-- 101167: double (nullable = true)
#  |-- 101168: double (nullable = true)
#  |-- 101259: double (nullable = true)
#  |-- 101260: double (nullable = true)
#  |-- 101261: double (nullable = true)
#  |-- 101263: double (nullable = true)
#  |-- 101264: double (nullable = true)
#  |-- 101265: double (nullable = true)
#  |-- 101266: double (nullable = true)
#  |-- 101268: double (nullable = true)
#  |-- 101269: double (nullable = true)
#  |-- 101270: double (nullable = true)
#  |-- 101271: double (nullable = true)
#  |-- 101272: double (nullable = true)
#  |-- 101273: double (nullable = true)
#  |-- 101275: double (nullable = true)
#  |-- 101277: double (nullable = true)
#  |-- 101278: double (nullable = true)
#  |-- 101279: double (nullable = true)
#  |-- 101280: double (nullable = true)
#  |-- 101413: double (nullable = true)
#  |-- 101414: double (nullable = true)
#  |-- 101415: double (nullable = true)
#  |-- 101416: double (nullable = true)
#  |-- 101417: double (nullable = true)
#  |-- 101418: double (nullable = true)
#  |-- 101419: double (nullable = true)
#  |-- 101420: double (nullable = true)
#  |-- 101421: double (nullable = true)
#  |-- 101422: double (nullable = true)
#  |-- 101423: double (nullable = true)
#  |-- 101425: double (nullable = true)
#  |-- 101427: double (nullable = true)
#  |-- 101428: double (nullable = true)
#  |-- 101429: double (nullable = true)
#  |-- 101430: double (nullable = true)
#  |-- 101431: double (nullable = true)
#  |-- 101432: double (nullable = true)
#  |-- 101433: double (nullable = true)
#  |-- 101434: double (nullable = true)
#  |-- 101435: double (nullable = true)
#  |-- 101437: double (nullable = true)
#  |-- 101440: double (nullable = true)
#  |-- 101441: double (nullable = true)
#  |-- 101442: double (nullable = true)
#  |-- 101445: double (nullable = true)
#  |-- 101447: double (nullable = true)
#  |-- 101449: double (nullable = true)
#  |-- 101454: double (nullable = true)
#  |-- 101456: double (nullable = true)
#  |-- 101468: double (nullable = true)
#  |-- 101470: double (nullable = true)
#  |-- 101475: double (nullable = true)
#  |-- 101477: double (nullable = true)
#  |-- 101480: double (nullable = true)
#  |-- 101484: double (nullable = true)
#  |-- 101485: double (nullable = true)
#  |-- 101487: double (nullable = true)
#  |-- 101489: double (nullable = true)
#  |-- 101490: double (nullable = true)
#  |-- 101526: double (nullable = true)
#  |-- 101537: double (nullable = true)
#  |-- 101555: double (nullable = true)
#  |-- 101556: double (nullable = true)
#  |-- 101557: double (nullable = true)
#  |-- 101558: double (nullable = true)
#  |-- 101561: double (nullable = true)
#  |-- 101563: double (nullable = true)
#  |-- 101564: double (nullable = true)
#  |-- 101565: double (nullable = true)
#  |-- 101569: double (nullable = true)
#  |-- 101572: double (nullable = true)
#  |-- 101576: double (nullable = true)
#  |-- 101577: double (nullable = true)
#  |-- 101578: double (nullable = true)
#  |-- 101601: double (nullable = true)
#  |-- 110101: double (nullable = true)
#  |-- 202004: double (nullable = true)
#  |-- 202005: double (nullable = true)
#  |-- 202006: double (nullable = true)
#  |-- 202073: double (nullable = true)
#  |-- 202074: double (nullable = true)
#  |-- 202075: double (nullable = true)
#  |-- 202078: double (nullable = true)
#  |-- 202143: double (nullable = true)
#  |-- 202144: double (nullable = true)
#  |-- 202145: double (nullable = true)
#  |-- 202146: double (nullable = true)
#  |-- 202147: double (nullable = true)
#  |-- 202148: double (nullable = true)
#  |-- 202253: double (nullable = true)
#  |-- 202254: double (nullable = true)
#  |-- 202255: double (nullable = true)
#  |-- 202256: double (nullable = true)
#  |-- 202257: double (nullable = true)
#  |-- 202258: double (nullable = true)
#  |-- 202261: double (nullable = true)
#  |-- 202262: double (nullable = true)
#  |-- 202263: double (nullable = true)
#  |-- 202319: double (nullable = true)
#  |-- 202320: double (nullable = true)
#  |-- 202328: double (nullable = true)
#  |-- 202329: double (nullable = true)
#  |-- 202330: double (nullable = true)
#  |-- 202332: double (nullable = true)
#  |-- 202437: double (nullable = true)
#  |-- 202438: double (nullable = true)
#  |-- 202439: double (nullable = true)
#  |-- 202444: double (nullable = true)
#  |-- 202447: double (nullable = true)
#  |-- 202449: double (nullable = true)
#  |-- 202534: double (nullable = true)
#  |-- 202535: double (nullable = true)
#  |-- 303134: double (nullable = true)
#  |-- 303135: double (nullable = true)
#  |-- 303202: double (nullable = true)
#  |-- 303506: double (nullable = true)
#  |-- 303507: double (nullable = true)
#  |-- 303508: double (nullable = true)
#  |-- 303509: double (nullable = true)
#  |-- 303617: double (nullable = true)
#  |-- 303631: double (nullable = true)
#  |-- 303705: double (nullable = true)
#  |-- 303713: double (nullable = true)
#  |-- 303727: double (nullable = true)
#  |-- 303728: double (nullable = true)
#  |-- 303729: double (nullable = true)
#  |-- 303730: double (nullable = true)
#  |-- 303731: double (nullable = true)
#  |-- 303732: double (nullable = true)
#  |-- 303809: double (nullable = true)
#  |-- 303813: double (nullable = true)
#  |-- 303815: double (nullable = true)
#  |-- 303837: double (nullable = true)
#  |-- 303838: double (nullable = true)
#  |-- 303839: double (nullable = true)
#  |-- 303840: double (nullable = true)
#  |-- 303841: double (nullable = true)
#  |-- 303842: double (nullable = true)
#  |-- 303844: double (nullable = true)
#  |-- 303845: double (nullable = true)
#  |-- 303847: double (nullable = true)
#  |-- 303848: double (nullable = true)
#  |-- 303914: double (nullable = true)
#  |-- 303915: double (nullable = true)
#  |-- 303916: double (nullable = true)
#  |-- 303917: double (nullable = true)
#  |-- 404012: double (nullable = true)
#  |-- 404013: double (nullable = true)
#  |-- 404014: double (nullable = true)
#  |-- 404015: double (nullable = true)
#  |-- 404016: double (nullable = true)
#  |-- 404017: double (nullable = true)
#  |-- 404018: double (nullable = true)
#  |-- 404113: double (nullable = true)
#  |-- 404115: double (nullable = true)
#  |-- 404117: double (nullable = true)
#  |-- 404118: double (nullable = true)
#  |-- 404120: double (nullable = true)
#  |-- 404121: double (nullable = true)
#  |-- 404122: double (nullable = true)
#  |-- 404215: double (nullable = true)
#  |-- 404217: double (nullable = true)
#  |-- 404219: double (nullable = true)
#  |-- 404320: double (nullable = true)
#  |-- 404324: double (nullable = true)
#  |-- 404325: double (nullable = true)
#  |-- 404326: double (nullable = true)
#  |-- 404327: double (nullable = true)
#  |-- 404328: double (nullable = true)
#  |-- 404416: double (nullable = true)
#  |-- 404417: double (nullable = true)
#  |-- 404418: double (nullable = true)
#  |-- 404419: double (nullable = true)
#  |-- 404513: double (nullable = true)
#  |-- 404514: double (nullable = true)
#  |-- 404614: double (nullable = true)
#  |-- 404615: double (nullable = true)
#  |-- 404617: double (nullable = true)
#  |-- 404707: double (nullable = true)
#  |-- 506017: double (nullable = true)
#  |-- 506067: double (nullable = true)
#  |-- 506091: double (nullable = true)
#  |-- 506093: double (nullable = true)
#  |-- 506401: double (nullable = true)
#  |-- 506402: double (nullable = true)
#  |-- 506404: double (nullable = true)
#  |-- 506405: double (nullable = true)
#  |-- 506406: double (nullable = true)
#  |-- 506408: double (nullable = true)
#  |-- 506409: double (nullable = true)
#  |-- 506521: double (nullable = true)
#  |-- 506571: double (nullable = true)
#  |-- 506581: double (nullable = true)
#  |-- 506586: double (nullable = true)
#  |-- 506612: double (nullable = true)
#  |-- 506624: double (nullable = true)
#  |-- 506631: double (nullable = true)
#  |-- 506663: double (nullable = true)
#  |-- 506669: double (nullable = true)
#  |-- 506741: double (nullable = true)
#  |-- 506758: double (nullable = true)
#  |-- 506761: double (nullable = true)
#  |-- 506771: double (nullable = true)
#  |-- 506773: double (nullable = true)
#  |-- 705101: double (nullable = true)
#  |-- 705103: double (nullable = true)
#  |-- 801302: double (nullable = true)
#  |-- 909301: double (nullable = true)
#  |-- unscaled_continuous_features: vector (nullable = true)
#  |-- scaled_features: vector (nullable = true)

# %% [markdown]
# #### Increase of the imporance of the financial variables (money)

# %%
listaPesos=([1]*727)
listaPesos[0:17]=[4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4]
VectorPesos=DenseVector(listaPesos)

# %%
transformer = ElementwiseProduct(scalingVec=VectorPesos,
                                 inputCol="scaled_features", outputCol="features")
# Batch transform the vectors to create new column:
dfBufferFeature=transformer.transform(dfBufferScaled)

# %%
dfBufferFeature.select('scaled_features','features').show(1,truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |scaled_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[0.5327628205271195,0.41771078373050063,-0.6417464834276211,-0.48398826617307067,-0.41448232250153494,0.08580702624523506,-0.2792286020346407,0.5660372916190081,-1.185716973679534,-0.08019513342769642,-0.17265172145288013,-0.35660941974393895,2.366786932365902,-0.13821365030973548,-0.14780424119091756,2.048921908895636,-0.6538075122783461,6.954067609778822E-4,0.07471247182111401,0.01919466229716212,0.02503559921546633,0.03436383668984584,0.020657837016620988,0.02919370826712894,0.021438456868502976,0.012536223976533277,0.01629683201221273,0.01748218540799123,0.04935547650966741,0.038973941931858005,0.01263292240536772,0.015942073962956167,0.0056160724183994684,0.009281881319148795,0.00408315286655143,0.004098748940507206,0.005188727724142605,0.004791860890095002,0.004948986016984198,6.954067609778824E-4,0.002939086648078994,0.006477642959684352,0.0,0.00345597176306668,6.954067609778824E-4,0.003057634094179465,0.00310309823835521,6.954067609778822E-4,0.001896240670790263,8.047799321359202E-4,6.954067609778824E-4,0.0011653253091783748,0.007934829705932383,0.0011217491979951407,0.010429054069209916,0.001423920030280936,6.954067609778822E-4,6.954067609778822E-4,0.001051998426086889,0.0022111597634668244,6.954067609778822E-4,0.00573157759762805,6.954067609778824E-4,6.954067609778822E-4,0.008314368330057883,8.089664105411376E-4,0.0,0.0061954013783150665,6.954067609778824E-4,9.826476609765653E-4,6.954067609778821E-4,6.954067609778822E-4,6.954067609778822E-4,0.007560891167285439,0.0016605870286607205,9.572008387619694E-4,0.004196983332830741,0.0,0.005316344269592891,0.0012330849975094233,0.0014337284051757345,6.954067609778824E-4,0.002191129571458072,0.0,7.974447917487464E-4,6.954067609778824E-4,0.007496805629966831,0.0,0.0,6.954067609778824E-4,0.0030886857559645365,0.005313880375711689,0.07823641882830591,0.0664214499848696,6.954067609778822E-4,0.001602576773396182,0.0018182807014976037,9.483426360207308E-4,8.980053179988084E-4,9.427848018532666E-4,0.0017058090622971939,0.009801200881757594,6.954067609778824E-4,9.723884374366976E-4,0.0076464328593388725,0.0,0.0021462096951325575,0.004126099897951375,0.006835069866205643,0.002601435378515097,6.954067609778824E-4,0.002013334829247799,0.0018216751873219932,0.0016720247337122626,0.005083243696408979,0.0018241747326831292,0.002346614291420319,0.0018849559850491373,0.0011189551243886294,0.00415112745871208,0.0010799266069201354,0.0018857440699184915,0.0016993585572422406,0.001507518895673009,0.0024709085661601955,0.001100076733136079,0.0011823565941679922,9.875708102973764E-4,0.0,0.0,0.0018153536072124895,0.018439791474056326,0.002296064362052246,6.954067609778822E-4,0.00510488270447279,0.006800154460364,9.814641503063182E-4,6.954067609778824E-4,0.004747284531938036,0.0011887278014776398,0.0,0.008216838494149828,8.355167928420001E-4,0.0,0.0016597872048628103,6.954067609778824E-4,0.0,0.0,8.237470403756157E-4,6.954067609778822E-4,0.0010172845733079144,6.954067609778824E-4,6.954067609778822E-4,6.954067609778822E-4,0.00125902602441373,8.975169060275026E-4,0.0011978087279667512,0.0010891304611749678,0.002518803169240813,0.002230967290099745,9.442909699456397E-4,0.001040748714866847,0.0014017855606344182,0.002549625294082132,0.004370340355315706,9.258483739177632E-4,0.0011036229479470371,8.622316044187453E-4,0.0010621385672838991,0.0,0.0,9.175210312788552E-4,9.765822527543011E-4,0.0010675253989180762,6.954067609778821E-4,6.954067609778822E-4,0.0,0.0013799542855806644,0.0011254879845036263,8.65093810801113E-4,0.001097391222084164,0.0,9.192737041561026E-4,0.008095376775380228,8.108430223161303E-4,0.001187848723250036,9.06627569193678E-4,6.954067609778822E-4,6.954067609778822E-4,9.507027042001582E-4,6.954067609778825E-4,6.954067609778821E-4,0.0,9.785713213757508E-4,9.456144518684207E-4,0.0019366628292693461,7.775756152785178E-4,7.071886074264519E-4,8.540748489508117E-4,0.0010196774733188519,0.001254029790950077,0.0,0.0,6.954067609778824E-4,6.954067609778824E-4,0.0012526821299185989,8.0550040532036 ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 1 row

# %% [markdown]
# ### Dimensionality reduction (WIP)

# %%
pca = PCA(k=120, inputCol="features", outputCol="pca_features")

# %%
pcamodel = pca.fit(dfBufferFeature)

# %%
variance=pcamodel.explainedVariance

# %%
variance
# Out:
# DenseVector([0.0448, 0.0177, 0.0059, 0.0051, 0.0045, 0.0041, 0.0033, 0.0033, 0.0031, 0.003, 0.0028, 0.0028, 0.0028, 0.0026, 0.0026, 0.0025, 0.0025, 0.0025, 0.0024, 0.0024, 0.0024, 0.0023, 0.0022, 0.0022, 0.0021, 0.0021, 0.0021, 0.0021, 0.0021, 0.0021, 0.0021, 0.002, 0.002, 0.002, 0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015])

# %%
variance.sum()
# Out:
# 0.29033780953685812

# %%
dfBufferFeaturePCA=pcamodel.transform(dfBufferFeature)

# %% [markdown]
# ### K Evaluation

# %%
listaErrores=[]

for k in range(2,51):
    #print(k)
    kmeans = KMeans().setK(k).setSeed(666)
    #kmeans = BisectingKMeans().setK(k).setSeed(666)
    model = kmeans.fit(dfBufferFeature)
    wssse = model.computeCost(dfBufferFeature)
    print("Within Set Sum of Squared Errors {} = ".format(k) + str(wssse))
    listaErrores.append((k,wssse))
# Out:
# Within Set Sum of Squared Errors 2 = 1393070501.1576726
# Within Set Sum of Squared Errors 3 = 1378412741.7343137
# Within Set Sum of Squared Errors 4 = 1377461685.790069
# Within Set Sum of Squared Errors 5 = 1365889624.0875635
# Within Set Sum of Squared Errors 6 = 1363443537.291437
# Within Set Sum of Squared Errors 7 = 1362266512.598531
# Within Set Sum of Squared Errors 8 = 1360177369.0779493
# Within Set Sum of Squared Errors 9 = 1355857063.9648836
# Within Set Sum of Squared Errors 10 = 1354647634.1814885
# Within Set Sum of Squared Errors 11 = 1349916948.3408916
# Within Set Sum of Squared Errors 12 = 1350353189.3224921
# Within Set Sum of Squared Errors 13 = 1348084286.237533
# Within Set Sum of Squared Errors 14 = 1346759306.167523
# Within Set Sum of Squared Errors 15 = 1347960251.390117
# Within Set Sum of Squared Errors 16 = 1343489663.5291505
# Within Set Sum of Squared Errors 17 = 1340514954.1560385
# Within Set Sum of Squared Errors 18 = 1339463624.5741982
# Within Set Sum of Squared Errors 19 = 1344000988.5614214
# Within Set Sum of Squared Errors 20 = 1339114720.4926212
# Within Set Sum of Squared Errors 21 = 1333538057.2407475
# Within Set Sum of Squared Errors 22 = 1328689659.8414168
# Within Set Sum of Squared Errors 23 = 1328408351.46558
# Within Set Sum of Squared Errors 24 = 1326150162.0545788
# Within Set Sum of Squared Errors 25 = 1327274800.179939
# Within Set Sum of Squared Errors 26 = 1323868900.814417
# Within Set Sum of Squared Errors 27 = 1321984998.2570767
# Within Set Sum of Squared Errors 28 = 1321723633.898158
# Within Set Sum of Squared Errors 29 = 1318239935.8511884
# Within Set Sum of Squared Errors 30 = 1319861090.7889931
# Within Set Sum of Squared Errors 31 = 1318441641.0094197
# Within Set Sum of Squared Errors 32 = 1313825631.719939
# Within Set Sum of Squared Errors 33 = 1314900642.7596812
# Within Set Sum of Squared Errors 34 = 1313676890.3380718
# Within Set Sum of Squared Errors 35 = 1310131924.9452481
# Within Set Sum of Squared Errors 36 = 1309076204.277065
# Within Set Sum of Squared Errors 37 = 1309889302.240694
# Within Set Sum of Squared Errors 38 = 1307492492.6467707
# Within Set Sum of Squared Errors 39 = 1305584730.6964421
# Within Set Sum of Squared Errors 40 = 1304875675.3933704
# Within Set Sum of Squared Errors 41 = 1303635859.5763843
# Within Set Sum of Squared Errors 42 = 1301867790.5939696
# Within Set Sum of Squared Errors 43 = 1298657472.3531003
# Within Set Sum of Squared Errors 44 = 1294149099.3486366
# Within Set Sum of Squared Errors 45 = 1294540979.0170686
# Within Set Sum of Squared Errors 46 = 1292952839.3457034
# Within Set Sum of Squared Errors 47 = 1295723422.6612334
# Within Set Sum of Squared Errors 48 = 1295675695.5083752
# Within Set Sum of Squared Errors 49 = 1287703140.6495616
# Within Set Sum of Squared Errors 50 = 1290486007.58073

# %%
pdErrors=pd.DataFrame.from_records(listaErrores, columns=['clusters','wssse'])

# %%
plt.clf()
plt.plot(pdErrors.clusters,pdErrors.wssse)
plt.show()

# %%
dfErrors=spark.createDataFrame(pdErrors)

# %%
# dfErrors.write.parquet("/analytics/bc1_clustering/tables/dfErrorsBin")

# %% [markdown]
# ### Segmentation final model

# %%
#kmeans = KMeans().setK(16).setSeed(666)
kmeans = BisectingKMeans().setK(20).setMinDivisibleClusterSize(40000).setSeed(666)

# %%
dfBufferFeature.select("ACCOUNTPK","features").show(5)
# Out:
# +---------+--------------------+
# |ACCOUNTPK|            features|
# +---------+--------------------+
# |    67805|[2.13105128210847...|
# |   109366|[2.13105128210847...|
# |   140126|[-14.216918189454...|
# |   142317|[-0.6962453910507...|
# |   164347|[2.13105128210847...|
# +---------+--------------------+
# only showing top 5 rows

# %%
model = kmeans.fit(dfBufferFeature)

# %% [markdown]
# ### Financial Product Inclination

# %% [markdown]
# #### Train

# %%
dfTrainRes=model.transform(dfBufferFeature).select(col("ACCOUNTPK").alias("ACCOUNT"),"prediction")

# %%
dfProdIncl=dfTrainRes.join(dfBuffer,dfTrainRes.ACCOUNT==dfTsys.ACCOUNTPK,'left_outer').fillna(0)

# %%
dfProdIncl.printSchema()
# Out:
# root
#  |-- ACCOUNT: long (nullable = true)
#  |-- prediction: integer (nullable = true)
#  |-- ACCOUNTPK: long (nullable = true)
#  |-- BALANCE: double (nullable = false)
#  |-- INSTALMENTBALANCEFOROVLMCHECK: double (nullable = false)
#  |-- CREDITLIMIT: double (nullable = false)
#  |-- LimitUse: double (nullable = false)
#  |-- LimitOffUs: double (nullable = false)
#  |-- LimitPersLoan: double (nullable = false)
#  |-- LimitCashOut: double (nullable = false)
#  |-- CLOSING_BALANCE: double (nullable = false)
#  |-- INSTALLMENTSOFFERS: long (nullable = true)
#  |-- Emprestimo_Pessoal: long (nullable = true)
#  |-- Pagamento_de_Contas: long (nullable = true)
#  |-- Parcelamento_Fatura_Automatico: long (nullable = true)
#  |-- Parcelamento_Fatura_Facil: long (nullable = true)
#  |-- Saque_Parcelado: long (nullable = true)
#  |-- Saque_a_Vista: long (nullable = true)
#  |-- Overlimit: long (nullable = true)
#  |-- Overlimit_Auth: integer (nullable = true)
#  |-- NULO: double (nullable = false)
#  |-- 0742: double (nullable = false)
#  |-- 0763: double (nullable = false)
#  |-- 0780: double (nullable = false)
#  |-- 1520: double (nullable = false)
#  |-- 1711: double (nullable = false)
#  |-- 1731: double (nullable = false)
#  |-- 1740: double (nullable = false)
#  |-- 1750: double (nullable = false)
#  |-- 1761: double (nullable = false)
#  |-- 1771: double (nullable = false)
#  |-- 1799: double (nullable = false)
#  |-- 2741: double (nullable = false)
#  |-- 2791: double (nullable = false)
#  |-- 2842: double (nullable = false)
#  |-- 3000: double (nullable = false)
#  |-- 3001: double (nullable = false)
#  |-- 3005: double (nullable = false)
#  |-- 3007: double (nullable = false)
#  |-- 3008: double (nullable = false)
#  |-- 3009: double (nullable = false)
#  |-- 3010: double (nullable = false)
#  |-- 3011: double (nullable = false)
#  |-- 3012: double (nullable = false)
#  |-- 3013: double (nullable = false)
#  |-- 3014: double (nullable = false)
#  |-- 3015: double (nullable = false)
#  |-- 3016: double (nullable = false)
#  |-- 3017: double (nullable = false)
#  |-- 3018: double (nullable = false)
#  |-- 3020: double (nullable = false)
#  |-- 3025: double (nullable = false)
#  |-- 3026: double (nullable = false)
#  |-- 3028: double (nullable = false)
#  |-- 3029: double (nullable = false)
#  |-- 3030: double (nullable = false)
#  |-- 3034: double (nullable = false)
#  |-- 3035: double (nullable = false)
#  |-- 3039: double (nullable = false)
#  |-- 3042: double (nullable = false)
#  |-- 3043: double (nullable = false)
#  |-- 3047: double (nullable = false)
#  |-- 3048: double (nullable = false)
#  |-- 3051: double (nullable = false)
#  |-- 3052: double (nullable = false)
#  |-- 3056: double (nullable = false)
#  |-- 3057: double (nullable = false)
#  |-- 3058: double (nullable = false)
#  |-- 3066: double (nullable = false)
#  |-- 3069: double (nullable = false)
#  |-- 3076: double (nullable = false)
#  |-- 3077: double (nullable = false)
#  |-- 3079: double (nullable = false)
#  |-- 3082: double (nullable = false)
#  |-- 3088: double (nullable = false)
#  |-- 3098: double (nullable = false)
#  |-- 3102: double (nullable = false)
#  |-- 3127: double (nullable = false)
#  |-- 3132: double (nullable = false)
#  |-- 3136: double (nullable = false)
#  |-- 3161: double (nullable = false)
#  |-- 3171: double (nullable = false)
#  |-- 3174: double (nullable = false)
#  |-- 3180: double (nullable = false)
#  |-- 3182: double (nullable = false)
#  |-- 3187: double (nullable = false)
#  |-- 3206: double (nullable = false)
#  |-- 3211: double (nullable = false)
#  |-- 3217: double (nullable = false)
#  |-- 3219: double (nullable = false)
#  |-- 3221: double (nullable = false)
#  |-- 3236: double (nullable = false)
#  |-- 3239: double (nullable = false)
#  |-- 3245: double (nullable = false)
#  |-- 3246: double (nullable = false)
#  |-- 3247: double (nullable = false)
#  |-- 3248: double (nullable = false)
#  |-- 3256: double (nullable = false)
#  |-- 3260: double (nullable = false)
#  |-- 3261: double (nullable = false)
#  |-- 3294: double (nullable = false)
#  |-- 3296: double (nullable = false)
#  |-- 3351: double (nullable = false)
#  |-- 3355: double (nullable = false)
#  |-- 3357: double (nullable = false)
#  |-- 3359: double (nullable = false)
#  |-- 3364: double (nullable = false)
#  |-- 3366: double (nullable = false)
#  |-- 3374: double (nullable = false)
#  |-- 3381: double (nullable = false)
#  |-- 3387: double (nullable = false)
#  |-- 3389: double (nullable = false)
#  |-- 3390: double (nullable = false)
#  |-- 3393: double (nullable = false)
#  |-- 3395: double (nullable = false)
#  |-- 3405: double (nullable = false)
#  |-- 3441: double (nullable = false)
#  |-- 3501: double (nullable = false)
#  |-- 3502: double (nullable = false)
#  |-- 3503: double (nullable = false)
#  |-- 3504: double (nullable = false)
#  |-- 3505: double (nullable = false)
#  |-- 3506: double (nullable = false)
#  |-- 3508: double (nullable = false)
#  |-- 3509: double (nullable = false)
#  |-- 3510: double (nullable = false)
#  |-- 3512: double (nullable = false)
#  |-- 3513: double (nullable = false)
#  |-- 3515: double (nullable = false)
#  |-- 3516: double (nullable = false)
#  |-- 3517: double (nullable = false)
#  |-- 3520: double (nullable = false)
#  |-- 3528: double (nullable = false)
#  |-- 3530: double (nullable = false)
#  |-- 3533: double (nullable = false)
#  |-- 3535: double (nullable = false)
#  |-- 3543: double (nullable = false)
#  |-- 3548: double (nullable = false)
#  |-- 3549: double (nullable = false)
#  |-- 3553: double (nullable = false)
#  |-- 3555: double (nullable = false)
#  |-- 3562: double (nullable = false)
#  |-- 3563: double (nullable = false)
#  |-- 3567: double (nullable = false)
#  |-- 3579: double (nullable = false)
#  |-- 3581: double (nullable = false)
#  |-- 3583: double (nullable = false)
#  |-- 3584: double (nullable = false)
#  |-- 3586: double (nullable = false)
#  |-- 3590: double (nullable = false)
#  |-- 3591: double (nullable = false)
#  |-- 3596: double (nullable = false)
#  |-- 3602: double (nullable = false)
#  |-- 3604: double (nullable = false)
#  |-- 3607: double (nullable = false)
#  |-- 3608: double (nullable = false)
#  |-- 3612: double (nullable = false)
#  |-- 3615: double (nullable = false)
#  |-- 3617: double (nullable = false)
#  |-- 3621: double (nullable = false)
#  |-- 3628: double (nullable = false)
#  |-- 3629: double (nullable = false)
#  |-- 3631: double (nullable = false)
#  |-- 3637: double (nullable = false)
#  |-- 3638: double (nullable = false)
#  |-- 3640: double (nullable = false)
#  |-- 3641: double (nullable = false)
#  |-- 3642: double (nullable = false)
#  |-- 3644: double (nullable = false)
#  |-- 3649: double (nullable = false)
#  |-- 3650: double (nullable = false)
#  |-- 3654: double (nullable = false)
#  |-- 3656: double (nullable = false)
#  |-- 3660: double (nullable = false)
#  |-- 3662: double (nullable = false)
#  |-- 3665: double (nullable = false)
#  |-- 3667: double (nullable = false)
#  |-- 3668: double (nullable = false)
#  |-- 3672: double (nullable = false)
#  |-- 3676: double (nullable = false)
#  |-- 3680: double (nullable = false)
#  |-- 3687: double (nullable = false)
#  |-- 3690: double (nullable = false)
#  |-- 3692: double (nullable = false)
#  |-- 3693: double (nullable = false)
#  |-- 3695: double (nullable = false)
#  |-- 3700: double (nullable = false)
#  |-- 3703: double (nullable = false)
#  |-- 3709: double (nullable = false)
#  |-- 3715: double (nullable = false)
#  |-- 3719: double (nullable = false)
#  |-- 3721: double (nullable = false)
#  |-- 3722: double (nullable = false)
#  |-- 3726: double (nullable = false)
#  |-- 3728: double (nullable = false)
#  |-- 3730: double (nullable = false)
#  |-- 3731: double (nullable = false)
#  |-- 3737: double (nullable = false)
#  |-- 3742: double (nullable = false)
#  |-- 3750: double (nullable = false)
#  |-- 3751: double (nullable = false)
#  |-- 3765: double (nullable = false)
#  |-- 3769: double (nullable = false)
#  |-- 3771: double (nullable = false)
#  |-- 3773: double (nullable = false)
#  |-- 3774: double (nullable = false)
#  |-- 3778: double (nullable = false)
#  |-- 3779: double (nullable = false)
#  |-- 3780: double (nullable = false)
#  |-- 3782: double (nullable = false)
#  |-- 3792: double (nullable = false)
#  |-- 3793: double (nullable = false)
#  |-- 3795: double (nullable = false)
#  |-- 3808: double (nullable = false)
#  |-- 3811: double (nullable = false)
#  |-- 3812: double (nullable = false)
#  |-- 3813: double (nullable = false)
#  |-- 3814: double (nullable = false)
#  |-- 3816: double (nullable = false)
#  |-- 3824: double (nullable = false)
#  |-- 3825: double (nullable = false)
#  |-- 4011: double (nullable = false)
#  |-- 4111: double (nullable = false)
#  |-- 4112: double (nullable = false)
#  |-- 4119: double (nullable = false)
#  |-- 4121: double (nullable = false)
#  |-- 4131: double (nullable = false)
#  |-- 4214: double (nullable = false)
#  |-- 4215: double (nullable = false)
#  |-- 4225: double (nullable = false)
#  |-- 4411: double (nullable = false)
#  |-- 4457: double (nullable = false)
#  |-- 4468: double (nullable = false)
#  |-- 4511: double (nullable = false)
#  |-- 4582: double (nullable = false)
#  |-- 4722: double (nullable = false)
#  |-- 4723: double (nullable = false)
#  |-- 4784: double (nullable = false)
#  |-- 4789: double (nullable = false)
#  |-- 4812: double (nullable = false)
#  |-- 4813: double (nullable = false)
#  |-- 4814: double (nullable = false)
#  |-- 4816: double (nullable = false)
#  |-- 4821: double (nullable = false)
#  |-- 4829: double (nullable = false)
#  |-- 4899: double (nullable = false)
#  |-- 4900: double (nullable = false)
#  |-- 5013: double (nullable = false)
#  |-- 5021: double (nullable = false)
#  |-- 5039: double (nullable = false)
#  |-- 5044: double (nullable = false)
#  |-- 5045: double (nullable = false)
#  |-- 5046: double (nullable = false)
#  |-- 5047: double (nullable = false)
#  |-- 5051: double (nullable = false)
#  |-- 5065: double (nullable = false)
#  |-- 5072: double (nullable = false)
#  |-- 5074: double (nullable = false)
#  |-- 5085: double (nullable = false)
#  |-- 5094: double (nullable = false)
#  |-- 5099: double (nullable = false)
#  |-- 5111: double (nullable = false)
#  |-- 5122: double (nullable = false)
#  |-- 5131: double (nullable = false)
#  |-- 5137: double (nullable = false)
#  |-- 5139: double (nullable = false)
#  |-- 5169: double (nullable = false)
#  |-- 5172: double (nullable = false)
#  |-- 5192: double (nullable = false)
#  |-- 5193: double (nullable = false)
#  |-- 5198: double (nullable = false)
#  |-- 5199: double (nullable = false)
#  |-- 5200: double (nullable = false)
#  |-- 5211: double (nullable = false)
#  |-- 5231: double (nullable = false)
#  |-- 5251: double (nullable = false)
#  |-- 5261: double (nullable = false)
#  |-- 5271: double (nullable = false)
#  |-- 5300: double (nullable = false)
#  |-- 5309: double (nullable = false)
#  |-- 5310: double (nullable = false)
#  |-- 5311: double (nullable = false)
#  |-- 5331: double (nullable = false)
#  |-- 5399: double (nullable = false)
#  |-- 5411: double (nullable = false)
#  |-- 5422: double (nullable = false)
#  |-- 5441: double (nullable = false)
#  |-- 5451: double (nullable = false)
#  |-- 5462: double (nullable = false)
#  |-- 5499: double (nullable = false)
#  |-- 5511: double (nullable = false)
#  |-- 5521: double (nullable = false)
#  |-- 5531: double (nullable = false)
#  |-- 5532: double (nullable = false)
#  |-- 5533: double (nullable = false)
#  |-- 5541: double (nullable = false)
#  |-- 5542: double (nullable = false)
#  |-- 5551: double (nullable = false)
#  |-- 5561: double (nullable = false)
#  |-- 5571: double (nullable = false)
#  |-- 5592: double (nullable = false)
#  |-- 5598: double (nullable = false)
#  |-- 5599: double (nullable = false)
#  |-- 5611: double (nullable = false)
#  |-- 5621: double (nullable = false)
#  |-- 5631: double (nullable = false)
#  |-- 5641: double (nullable = false)
#  |-- 5651: double (nullable = false)
#  |-- 5655: double (nullable = false)
#  |-- 5661: double (nullable = false)
#  |-- 5681: double (nullable = false)
#  |-- 5691: double (nullable = false)
#  |-- 5697: double (nullable = false)
#  |-- 5698: double (nullable = false)
#  |-- 5699: double (nullable = false)
#  |-- 5712: double (nullable = false)
#  |-- 5713: double (nullable = false)
#  |-- 5714: double (nullable = false)
#  |-- 5718: double (nullable = false)
#  |-- 5719: double (nullable = false)
#  |-- 5722: double (nullable = false)
#  |-- 5732: double (nullable = false)
#  |-- 5733: double (nullable = false)
#  |-- 5734: double (nullable = false)
#  |-- 5735: double (nullable = false)
#  |-- 5811: double (nullable = false)
#  |-- 5812: double (nullable = false)
#  |-- 5813: double (nullable = false)
#  |-- 5814: double (nullable = false)
#  |-- 5815: double (nullable = false)
#  |-- 5816: double (nullable = false)
#  |-- 5817: double (nullable = false)
#  |-- 5818: double (nullable = false)
#  |-- 5912: double (nullable = false)
#  |-- 5921: double (nullable = false)
#  |-- 5931: double (nullable = false)
#  |-- 5932: double (nullable = false)
#  |-- 5933: double (nullable = false)
#  |-- 5935: double (nullable = false)
#  |-- 5937: double (nullable = false)
#  |-- 5940: double (nullable = false)
#  |-- 5941: double (nullable = false)
#  |-- 5942: double (nullable = false)
#  |-- 5943: double (nullable = false)
#  |-- 5944: double (nullable = false)
#  |-- 5945: double (nullable = false)
#  |-- 5946: double (nullable = false)
#  |-- 5947: double (nullable = false)
#  |-- 5948: double (nullable = false)
#  |-- 5949: double (nullable = false)
#  |-- 5950: double (nullable = false)
#  |-- 5960: double (nullable = false)
#  |-- 5962: double (nullable = false)
#  |-- 5963: double (nullable = false)
#  |-- 5964: double (nullable = false)
#  |-- 5965: double (nullable = false)
#  |-- 5966: double (nullable = false)
#  |-- 5967: double (nullable = false)
#  |-- 5968: double (nullable = false)
#  |-- 5969: double (nullable = false)
#  |-- 5970: double (nullable = false)
#  |-- 5971: double (nullable = false)
#  |-- 5972: double (nullable = false)
#  |-- 5973: double (nullable = false)
#  |-- 5975: double (nullable = false)
#  |-- 5976: double (nullable = false)
#  |-- 5977: double (nullable = false)
#  |-- 5978: double (nullable = false)
#  |-- 5983: double (nullable = false)
#  |-- 5992: double (nullable = false)
#  |-- 5993: double (nullable = false)
#  |-- 5994: double (nullable = false)
#  |-- 5995: double (nullable = false)
#  |-- 5996: double (nullable = false)
#  |-- 5997: double (nullable = false)
#  |-- 5998: double (nullable = false)
#  |-- 5999: double (nullable = false)
#  |-- 6012: double (nullable = false)
#  |-- 6051: double (nullable = false)
#  |-- 6211: double (nullable = false)
#  |-- 6300: double (nullable = false)
#  |-- 6513: double (nullable = false)
#  |-- 6540: double (nullable = false)
#  |-- 7011: double (nullable = false)
#  |-- 7012: double (nullable = false)
#  |-- 7032: double (nullable = false)
#  |-- 7033: double (nullable = false)
#  |-- 7210: double (nullable = false)
#  |-- 7211: double (nullable = false)
#  |-- 7216: double (nullable = false)
#  |-- 7217: double (nullable = false)
#  |-- 7221: double (nullable = false)
#  |-- 7230: double (nullable = false)
#  |-- 7251: double (nullable = false)
#  |-- 7261: double (nullable = false)
#  |-- 7273: double (nullable = false)
#  |-- 7276: double (nullable = false)
#  |-- 7277: double (nullable = false)
#  |-- 7278: double (nullable = false)
#  |-- 7296: double (nullable = false)
#  |-- 7297: double (nullable = false)
#  |-- 7298: double (nullable = false)
#  |-- 7299: double (nullable = false)
#  |-- 7311: double (nullable = false)
#  |-- 7321: double (nullable = false)
#  |-- 7333: double (nullable = false)
#  |-- 7338: double (nullable = false)
#  |-- 7339: double (nullable = false)
#  |-- 7342: double (nullable = false)
#  |-- 7349: double (nullable = false)
#  |-- 7361: double (nullable = false)
#  |-- 7372: double (nullable = false)
#  |-- 7375: double (nullable = false)
#  |-- 7379: double (nullable = false)
#  |-- 7392: double (nullable = false)
#  |-- 7393: double (nullable = false)
#  |-- 7394: double (nullable = false)
#  |-- 7395: double (nullable = false)
#  |-- 7399: double (nullable = false)
#  |-- 7512: double (nullable = false)
#  |-- 7513: double (nullable = false)
#  |-- 7519: double (nullable = false)
#  |-- 7523: double (nullable = false)
#  |-- 7531: double (nullable = false)
#  |-- 7534: double (nullable = false)
#  |-- 7535: double (nullable = false)
#  |-- 7538: double (nullable = false)
#  |-- 7542: double (nullable = false)
#  |-- 7549: double (nullable = false)
#  |-- 7622: double (nullable = false)
#  |-- 7623: double (nullable = false)
#  |-- 7629: double (nullable = false)
#  |-- 7631: double (nullable = false)
#  |-- 7641: double (nullable = false)
#  |-- 7692: double (nullable = false)
#  |-- 7699: double (nullable = false)
#  |-- 7829: double (nullable = false)
#  |-- 7832: double (nullable = false)
#  |-- 7841: double (nullable = false)
#  |-- 7911: double (nullable = false)
#  |-- 7922: double (nullable = false)
#  |-- 7929: double (nullable = false)
#  |-- 7932: double (nullable = false)
#  |-- 7933: double (nullable = false)
#  |-- 7941: double (nullable = false)
#  |-- 7991: double (nullable = false)
#  |-- 7992: double (nullable = false)
#  |-- 7993: double (nullable = false)
#  |-- 7994: double (nullable = false)
#  |-- 7995: double (nullable = false)
#  |-- 7996: double (nullable = false)
#  |-- 7997: double (nullable = false)
#  |-- 7998: double (nullable = false)
#  |-- 7999: double (nullable = false)
#  |-- 8011: double (nullable = false)
#  |-- 8021: double (nullable = false)
#  |-- 8031: double (nullable = false)
#  |-- 8041: double (nullable = false)
#  |-- 8042: double (nullable = false)
#  |-- 8043: double (nullable = false)
#  |-- 8049: double (nullable = false)
#  |-- 8050: double (nullable = false)
#  |-- 8062: double (nullable = false)
#  |-- 8071: double (nullable = false)
#  |-- 8099: double (nullable = false)
#  |-- 8111: double (nullable = false)
#  |-- 8211: double (nullable = false)
#  |-- 8220: double (nullable = false)
#  |-- 8241: double (nullable = false)
#  |-- 8242: double (nullable = false)
#  |-- 8244: double (nullable = false)
#  |-- 8249: double (nullable = false)
#  |-- 8299: double (nullable = false)
#  |-- 8351: double (nullable = false)
#  |-- 8398: double (nullable = false)
#  |-- 8641: double (nullable = false)
#  |-- 8651: double (nullable = false)
#  |-- 8661: double (nullable = false)
#  |-- 8675: double (nullable = false)
#  |-- 8699: double (nullable = false)
#  |-- 8734: double (nullable = false)
#  |-- 8911: double (nullable = false)
#  |-- 8931: double (nullable = false)
#  |-- 8999: double (nullable = false)
#  |-- 9211: double (nullable = false)
#  |-- 9222: double (nullable = false)
#  |-- 9311: double (nullable = false)
#  |-- 9399: double (nullable = false)
#  |-- 9402: double (nullable = false)
#  |-- 9405: double (nullable = false)
#  |-- 101054: double (nullable = false)
#  |-- 101069: double (nullable = false)
#  |-- 101075: double (nullable = false)
#  |-- 101076: double (nullable = false)
#  |-- 101078: double (nullable = false)
#  |-- 101079: double (nullable = false)
#  |-- 101081: double (nullable = false)
#  |-- 101083: double (nullable = false)
#  |-- 101085: double (nullable = false)
#  |-- 101086: double (nullable = false)
#  |-- 101087: double (nullable = false)
#  |-- 101089: double (nullable = false)
#  |-- 101090: double (nullable = false)
#  |-- 101092: double (nullable = false)
#  |-- 101096: double (nullable = false)
#  |-- 101148: double (nullable = false)
#  |-- 101149: double (nullable = false)
#  |-- 101151: double (nullable = false)
#  |-- 101152: double (nullable = false)
#  |-- 101153: double (nullable = false)
#  |-- 101154: double (nullable = false)
#  |-- 101155: double (nullable = false)
#  |-- 101156: double (nullable = false)
#  |-- 101158: double (nullable = false)
#  |-- 101159: double (nullable = false)
#  |-- 101160: double (nullable = false)
#  |-- 101161: double (nullable = false)
#  |-- 101162: double (nullable = false)
#  |-- 101163: double (nullable = false)
#  |-- 101164: double (nullable = false)
#  |-- 101165: double (nullable = false)
#  |-- 101167: double (nullable = false)
#  |-- 101168: double (nullable = false)
#  |-- 101259: double (nullable = false)
#  |-- 101260: double (nullable = false)
#  |-- 101261: double (nullable = false)
#  |-- 101263: double (nullable = false)
#  |-- 101264: double (nullable = false)
#  |-- 101265: double (nullable = false)
#  |-- 101266: double (nullable = false)
#  |-- 101268: double (nullable = false)
#  |-- 101269: double (nullable = false)
#  |-- 101270: double (nullable = false)
#  |-- 101271: double (nullable = false)
#  |-- 101272: double (nullable = false)
#  |-- 101273: double (nullable = false)
#  |-- 101275: double (nullable = false)
#  |-- 101277: double (nullable = false)
#  |-- 101278: double (nullable = false)
#  |-- 101279: double (nullable = false)
#  |-- 101280: double (nullable = false)
#  |-- 101413: double (nullable = false)
#  |-- 101414: double (nullable = false)
#  |-- 101415: double (nullable = false)
#  |-- 101416: double (nullable = false)
#  |-- 101417: double (nullable = false)
#  |-- 101418: double (nullable = false)
#  |-- 101419: double (nullable = false)
#  |-- 101420: double (nullable = false)
#  |-- 101421: double (nullable = false)
#  |-- 101422: double (nullable = false)
#  |-- 101423: double (nullable = false)
#  |-- 101425: double (nullable = false)
#  |-- 101427: double (nullable = false)
#  |-- 101428: double (nullable = false)
#  |-- 101429: double (nullable = false)
#  |-- 101430: double (nullable = false)
#  |-- 101431: double (nullable = false)
#  |-- 101432: double (nullable = false)
#  |-- 101433: double (nullable = false)
#  |-- 101434: double (nullable = false)
#  |-- 101435: double (nullable = false)
#  |-- 101437: double (nullable = false)
#  |-- 101440: double (nullable = false)
#  |-- 101441: double (nullable = false)
#  |-- 101442: double (nullable = false)
#  |-- 101445: double (nullable = false)
#  |-- 101447: double (nullable = false)
#  |-- 101449: double (nullable = false)
#  |-- 101454: double (nullable = false)
#  |-- 101456: double (nullable = false)
#  |-- 101468: double (nullable = false)
#  |-- 101470: double (nullable = false)
#  |-- 101475: double (nullable = false)
#  |-- 101477: double (nullable = false)
#  |-- 101480: double (nullable = false)
#  |-- 101484: double (nullable = false)
#  |-- 101485: double (nullable = false)
#  |-- 101487: double (nullable = false)
#  |-- 101489: double (nullable = false)
#  |-- 101490: double (nullable = false)
#  |-- 101526: double (nullable = false)
#  |-- 101537: double (nullable = false)
#  |-- 101555: double (nullable = false)
#  |-- 101556: double (nullable = false)
#  |-- 101557: double (nullable = false)
#  |-- 101558: double (nullable = false)
#  |-- 101561: double (nullable = false)
#  |-- 101563: double (nullable = false)
#  |-- 101564: double (nullable = false)
#  |-- 101565: double (nullable = false)
#  |-- 101569: double (nullable = false)
#  |-- 101572: double (nullable = false)
#  |-- 101576: double (nullable = false)
#  |-- 101577: double (nullable = false)
#  |-- 101578: double (nullable = false)
#  |-- 101601: double (nullable = false)
#  |-- 110101: double (nullable = false)
#  |-- 202004: double (nullable = false)
#  |-- 202005: double (nullable = false)
#  |-- 202006: double (nullable = false)
#  |-- 202073: double (nullable = false)
#  |-- 202074: double (nullable = false)
#  |-- 202075: double (nullable = false)
#  |-- 202078: double (nullable = false)
#  |-- 202143: double (nullable = false)
#  |-- 202144: double (nullable = false)
#  |-- 202145: double (nullable = false)
#  |-- 202146: double (nullable = false)
#  |-- 202147: double (nullable = false)
#  |-- 202148: double (nullable = false)
#  |-- 202253: double (nullable = false)
#  |-- 202254: double (nullable = false)
#  |-- 202255: double (nullable = false)
#  |-- 202256: double (nullable = false)
#  |-- 202257: double (nullable = false)
#  |-- 202258: double (nullable = false)
#  |-- 202261: double (nullable = false)
#  |-- 202262: double (nullable = false)
#  |-- 202263: double (nullable = false)
#  |-- 202319: double (nullable = false)
#  |-- 202320: double (nullable = false)
#  |-- 202328: double (nullable = false)
#  |-- 202329: double (nullable = false)
#  |-- 202330: double (nullable = false)
#  |-- 202332: double (nullable = false)
#  |-- 202437: double (nullable = false)
#  |-- 202438: double (nullable = false)
#  |-- 202439: double (nullable = false)
#  |-- 202444: double (nullable = false)
#  |-- 202447: double (nullable = false)
#  |-- 202449: double (nullable = false)
#  |-- 202534: double (nullable = false)
#  |-- 202535: double (nullable = false)
#  |-- 303134: double (nullable = false)
#  |-- 303135: double (nullable = false)
#  |-- 303202: double (nullable = false)
#  |-- 303506: double (nullable = false)
#  |-- 303507: double (nullable = false)
#  |-- 303508: double (nullable = false)
#  |-- 303509: double (nullable = false)
#  |-- 303617: double (nullable = false)
#  |-- 303631: double (nullable = false)
#  |-- 303705: double (nullable = false)
#  |-- 303713: double (nullable = false)
#  |-- 303727: double (nullable = false)
#  |-- 303728: double (nullable = false)
#  |-- 303729: double (nullable = false)
#  |-- 303730: double (nullable = false)
#  |-- 303731: double (nullable = false)
#  |-- 303732: double (nullable = false)
#  |-- 303809: double (nullable = false)
#  |-- 303813: double (nullable = false)
#  |-- 303815: double (nullable = false)
#  |-- 303837: double (nullable = false)
#  |-- 303838: double (nullable = false)
#  |-- 303839: double (nullable = false)
#  |-- 303840: double (nullable = false)
#  |-- 303841: double (nullable = false)
#  |-- 303842: double (nullable = false)
#  |-- 303844: double (nullable = false)
#  |-- 303845: double (nullable = false)
#  |-- 303847: double (nullable = false)
#  |-- 303848: double (nullable = false)
#  |-- 303914: double (nullable = false)
#  |-- 303915: double (nullable = false)
#  |-- 303916: double (nullable = false)
#  |-- 303917: double (nullable = false)
#  |-- 404012: double (nullable = false)
#  |-- 404013: double (nullable = false)
#  |-- 404014: double (nullable = false)
#  |-- 404015: double (nullable = false)
#  |-- 404016: double (nullable = false)
#  |-- 404017: double (nullable = false)
#  |-- 404018: double (nullable = false)
#  |-- 404113: double (nullable = false)
#  |-- 404115: double (nullable = false)
#  |-- 404117: double (nullable = false)
#  |-- 404118: double (nullable = false)
#  |-- 404120: double (nullable = false)
#  |-- 404121: double (nullable = false)
#  |-- 404122: double (nullable = false)
#  |-- 404215: double (nullable = false)
#  |-- 404217: double (nullable = false)
#  |-- 404219: double (nullable = false)
#  |-- 404320: double (nullable = false)
#  |-- 404324: double (nullable = false)
#  |-- 404325: double (nullable = false)
#  |-- 404326: double (nullable = false)
#  |-- 404327: double (nullable = false)
#  |-- 404328: double (nullable = false)
#  |-- 404416: double (nullable = false)
#  |-- 404417: double (nullable = false)
#  |-- 404418: double (nullable = false)
#  |-- 404419: double (nullable = false)
#  |-- 404513: double (nullable = false)
#  |-- 404514: double (nullable = false)
#  |-- 404614: double (nullable = false)
#  |-- 404615: double (nullable = false)
#  |-- 404617: double (nullable = false)
#  |-- 404707: double (nullable = false)
#  |-- 506017: double (nullable = false)
#  |-- 506067: double (nullable = false)
#  |-- 506091: double (nullable = false)
#  |-- 506093: double (nullable = false)
#  |-- 506401: double (nullable = false)
#  |-- 506402: double (nullable = false)
#  |-- 506404: double (nullable = false)
#  |-- 506405: double (nullable = false)
#  |-- 506406: double (nullable = false)
#  |-- 506408: double (nullable = false)
#  |-- 506409: double (nullable = false)
#  |-- 506521: double (nullable = false)
#  |-- 506571: double (nullable = false)
#  |-- 506581: double (nullable = false)
#  |-- 506586: double (nullable = false)
#  |-- 506612: double (nullable = false)
#  |-- 506624: double (nullable = false)
#  |-- 506631: double (nullable = false)
#  |-- 506663: double (nullable = false)
#  |-- 506669: double (nullable = false)
#  |-- 506741: double (nullable = false)
#  |-- 506758: double (nullable = false)
#  |-- 506761: double (nullable = false)
#  |-- 506771: double (nullable = false)
#  |-- 506773: double (nullable = false)
#  |-- 705101: double (nullable = false)
#  |-- 705103: double (nullable = false)
#  |-- 801302: double (nullable = false)
#  |-- 909301: double (nullable = false)

# %%
dfProdIncl.createOrReplaceTempView("tProdIncl")

# %%
dfClusIncl=spark.sql("""SELECT prediction, 
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) Overlimit
    from tProdIncl group by prediction order by prediction""")

# %%
dfClusIncl.toPandas()
# Out:
#     prediction  Emprestimo_Pessoal  Pagamento_de_Contas  \
# 0            0            0.000000             0.000000
# 1            1            0.000055             0.001874
# 2            2            0.000461             0.002920
# 3            3            0.002085             0.003574
# 4            4            0.000066             0.000009
# 5            5            0.001151             0.003594
# 6            6            0.000163             0.001511
# 7            7            0.000000             0.000000
# 8            8            0.000000             0.000000
# 9            9            0.000000             0.000000
# 10          10            0.000000             0.000000
# 11          11            0.001218             0.691181
# 12          12            0.215743             0.098811
# 13          13            0.068248             0.176040
# 14          14            0.007328             0.091912
# 15          15            0.026361             0.106149
# 16          16            0.012943             0.032366
# 17          17            0.000318             0.044505
# 18          18            0.000298             0.024018
# 19          19            0.008767             0.047652
#
#     Parcelamento_Fatura_Automatico  Parcelamento_Fatura_Facil  \
# 0                         0.000000                   0.000000
# 1                         0.013637                   0.034406
# 2                         0.010807                   0.072358
# 3                         0.009729                   0.056132
# 4                         0.000014                   0.000033
# 5                         0.005396                   0.031596
# 6                         0.002939                   0.013186
# 7                         0.000000                   0.638970
# 8                         0.000000                   0.245920
# 9                         1.000000                   0.000000
# 10                        1.000000                   0.588867
# 11                        0.286362                   0.450733
# 12                        0.246079                   0.450906
# 13                        0.431279                   0.362085
# 14                        0.091504                   0.148818
# 15                        0.207589                   0.299538
# 16                        0.084062                   0.176189
# 17                        0.018529                   0.081457
# 18                        0.014993                   0.056516
# 19                        0.081026                   0.112360
#
#     Saque_Parcelado  Saque_a_Vista  Overlimit
# 0          0.000000       0.000000   0.000000
# 1          0.000188       0.000287   0.078817
# 2          0.001589       0.002478   0.038822
# 3          0.003217       0.002909   0.039523
# 4          0.000005       0.000000   0.000014
# 5          0.002183       0.002293   0.024218
# 6          0.000735       0.000816   0.011227
# 7          0.000000       0.000000   0.000000
# 8          0.000000       0.000000   1.000000
# 9          0.000000       0.000000   0.000000
# 10         0.000000       0.000000   0.590297
# 11         0.367709       0.017986   0.461293
# 12         0.179122       0.796636   0.390585
# 13         0.122635       0.133913   0.536088
# 14         0.035328       0.034219   0.408029
# 15         0.105915       0.094186   0.512269
# 16         0.011063       0.010317   0.101481
# 17         0.015953       0.016905   0.090739
# 18         0.009921       0.010567   0.075710
# 19         0.020050       0.027602   0.143304

# %%
dfTrainRes.select("ACCOUNT","prediction").groupBy("prediction").count().orderBy("prediction").toPandas()
# Out:
#     prediction   count
# 0            0  198175
# 1            1  180901
# 2            2  414068
# 3            3  100727
# 4            4  212516
# 5            5   99885
# 6            6   24495
# 7            7  116367
# 8            8  194169
# 9            9   70631
# 10          10   95806
# 11          11   50094
# 12          12   36919
# 13          13   27488
# 14          14   34250
# 15          15   55422
# 16          16   64357
# 17          17   28334
# 18          18   40219
# 19          19   23042

# %%
dfImportanceCluster=spark.sql("""
    SELECT prediction, 
    Emprestimo_Pessoal/AVG_Emprestimo_Pessoal AS Emprestimo_Pessoal, 
    Pagamento_de_Contas/AVG_Pagamento_de_Contas AS Pagamento_de_Contas,
    Parcelamento_Fatura_Automatico/AVG_Parcelamento_Fatura_Automatico AS Parcelamento_Fatura_Automatico,
    Parcelamento_Fatura_Facil/AVG_Parcelamento_Fatura_Facil AS Parcelamento_Fatura_Facil,
    Saque_Parcelado/AVG_Saque_Parcelado  AS Saque_Parcelado,
    Saque_a_Vista/AVG_Saque_a_Vista  AS Saque_a_Vista,
    Overlimit/AVG_Overlimit  AS Overlimit
    FROM
    (SELECT prediction, 
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) Overlimit
    from tProdIncl group by prediction) CLUSTER CROSS JOIN
    (SELECT  
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Overlimit
    from tProdIncl)
    WHERE 
    order by prediction""")

# %%
dfImportanceCluster.columns[1:]
# Out:
# ['Emprestimo_Pessoal',
#  'Pagamento_de_Contas',
#  'Parcelamento_Fatura_Automatico',
#  'Parcelamento_Fatura_Facil',
#  'Saque_Parcelado',
#  'Saque_a_Vista',
#  'Overlimit']

# %%
cond = "psf.when" + ".when".join(["(psf.col('" + c + "') == psf.col('max_value'), psf.lit('" + c + "'))" for c in dfImportanceCluster.columns[1:]])
import pyspark.sql.functions as psf
dfImportanceCluster.withColumn("max_value", psf.greatest(*dfImportanceCluster.columns[1:]))\
    .withColumn("MAX", eval(cond))\
    .toPandas()
# Out:
#     prediction  Emprestimo_Pessoal  Pagamento_de_Contas  \
# 0            0            0.000000             0.000000
# 1            1            0.008651             0.064740
# 2            2            0.072185             0.100872
# 3            3            0.326258             0.123473
# 4            4            0.010309             0.000325
# 5            5            0.180171             0.124168
# 6            6            0.025555             0.052184
# 7            7            0.000000             0.000000
# 8            8            0.000000             0.000000
# 9            9            0.000000             0.000000
# 10          10            0.000000             0.000000
# 11          11            0.190560            23.878444
# 12          12           33.761655             3.413653
# 13          13           10.680155             6.081728
# 14          14            1.146835             3.175328
# 15          15            4.125303             3.667171
# 16          16            2.025523             1.118170
# 17          17            0.049708             1.537523
# 18          18            0.046692             0.829775
# 19          19            1.371889             1.646253
#
#     Parcelamento_Fatura_Automatico  Parcelamento_Fatura_Facil  \
# 0                         0.000000                   0.000000
# 1                         0.120874                   0.227135
# 2                         0.095791                   0.477682
# 3                         0.086235                   0.370565
# 4                         0.000125                   0.000217
# 5                         0.047829                   0.208589
# 6                         0.026053                   0.087052
# 7                         0.000000                   4.218276
# 8                         0.000000                   1.623485
# 9                         8.863469                   0.000000
# 10                        8.863469                   3.887514
# 11                        2.538157                   2.975594
# 12                        2.181116                   2.976739
# 13                        3.822629                   2.390372
# 14                        0.811040                   0.982446
# 15                        1.839959                   1.977456
# 16                        0.745084                   1.163144
# 17                        0.164231                   0.537753
# 18                        0.132889                   0.373098
# 19                        0.718171                   0.741765
#
#     Saque_Parcelado  Saque_a_Vista  Overlimit  max_value  \
# 0          0.000000       0.000000   0.000000   0.000000
# 1          0.010027       0.013445   0.409695   0.409695
# 2          0.084775       0.115901   0.201801   0.477682
# 3          0.171599       0.136061   0.205442   0.370565
# 4          0.000251       0.000000   0.000073   0.010309
# 5          0.116432       0.107238   0.125886   0.208589
# 6          0.039202       0.038191   0.058358   0.087052
# 7          0.000000       0.000000   0.000000   4.218276
# 8          0.000000       0.000000   5.198083   5.198083
# 9          0.000000       0.000000   0.000000   8.863469
# 10         0.000000       0.000000   3.068413   8.863469
# 11        19.616428       0.841299   2.397838  23.878444
# 12         9.555746      37.262445   2.030292  37.262445
# 13         6.542317       6.263746   2.786632  10.680155
# 14         1.884694       1.600584   2.120970   3.175328
# 15         5.650305       4.405547   2.662819   5.650305
# 16         0.590201       0.482596   0.527506   2.025523
# 17         0.851033       0.790750   0.471669   1.537523
# 18         0.529246       0.494276   0.393549   0.829775
# 19         1.069640       1.291066   0.744904   1.646253
#
#                                MAX
# 0               Emprestimo_Pessoal
# 1                        Overlimit
# 2        Parcelamento_Fatura_Facil
# 3        Parcelamento_Fatura_Facil
# 4               Emprestimo_Pessoal
# 5        Parcelamento_Fatura_Facil
# 6        Parcelamento_Fatura_Facil
# 7        Parcelamento_Fatura_Facil
# 8                        Overlimit
# 9   Parcelamento_Fatura_Automatico
# 10  Parcelamento_Fatura_Automatico
# 11             Pagamento_de_Contas
# 12                   Saque_a_Vista
# 13              Emprestimo_Pessoal
# 14             Pagamento_de_Contas
# 15                 Saque_Parcelado
# 16              Emprestimo_Pessoal
# 17             Pagamento_de_Contas
# 18             Pagamento_de_Contas
# 19             Pagamento_de_Contas

# %%
#dfTrainRes.write.parquet("/analytics/bc1_clustering/tables/dfTrainRes")

# %%
#dfTrainRes=spark.read.parquet("/analytics/bc1_clustering/tables/dfTrainRes")
#dfTrainRes.persist()

# %% [markdown]
# #### Test

# %%
dfTestBufferFeatureTmp=sparkFeaturePipelineModel.transform(dfTestBuffer).persist()

# %%
dfTestBufferFeature=transformer.transform(dfTestBufferFeatureTmp)

# %%
dfTestRes=model.transform(dfTestBufferFeature).select(col("ACCOUNTPK").alias("ACCOUNT"),"prediction")

# %%
dfTestProdIncl=dfTestRes.join(dfTsys,dfTestRes.ACCOUNT==dfTsys.ACCOUNTPK,'left_outer').fillna(0)

# %%
dfTestProdIncl.printSchema()
# Out:
# root
#  |-- ACCOUNT: long (nullable = true)
#  |-- prediction: integer (nullable = true)
#  |-- ACCOUNTPK: long (nullable = true)
#  |-- Emprestimo_Pessoal: long (nullable = true)
#  |-- Pagamento_de_Contas: long (nullable = true)
#  |-- Parcelamento_Fatura_Automatico: long (nullable = true)
#  |-- Parcelamento_Fatura_Facil: long (nullable = true)
#  |-- Saque_Parcelado: long (nullable = true)
#  |-- Saque_a_Vista: long (nullable = true)
#  |-- Overlimit: long (nullable = true)

# %%
dfTestProdIncl.createOrReplaceTempView("tTestProdIncl")

# %%
dfTestClusIncl=spark.sql("""SELECT prediction, 
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) Overlimit
    from tTestProdIncl group by prediction order by prediction""")

# %%
dfTestClusIncl.toPandas()
# Out:
#     prediction  Emprestimo_Pessoal  Pagamento_de_Contas  \
# 0            0            0.000000             0.000000
# 1            1            0.000110             0.001931
# 2            2            0.000490             0.002760
# 3            3            0.001940             0.003304
# 4            4            0.000046             0.000005
# 5            5            0.001028             0.003420
# 6            6            0.000240             0.001479
# 7            7            0.000000             0.000000
# 8            8            0.000000             0.000000
# 9            9            0.000000             0.000000
# 10          10            0.000000             0.000000
# 11          11            0.001522             0.689090
# 12          12            0.219371             0.101179
# 13          13            0.067432             0.178719
# 14          14            0.006944             0.093940
# 15          15            0.025849             0.105384
# 16          16            0.012732             0.031768
# 17          17            0.000769             0.043422
# 18          18            0.000273             0.023247
# 19          19            0.009004             0.051342
#
#     Parcelamento_Fatura_Automatico  Parcelamento_Fatura_Facil  \
# 0                         0.000000                   0.000000
# 1                         0.013371                   0.034350
# 2                         0.011377                   0.073034
# 3                         0.009231                   0.057501
# 4                         0.000023                   0.000023
# 5                         0.005762                   0.031943
# 6                         0.003397                   0.013389
# 7                         0.000000                   0.643068
# 8                         0.000000                   0.245283
# 9                         1.000000                   0.000000
# 10                        1.000000                   0.589128
# 11                        0.281704                   0.451596
# 12                        0.247118                   0.453037
# 13                        0.434811                   0.365656
# 14                        0.092620                   0.150895
# 15                        0.204175                   0.297689
# 16                        0.083549                   0.173046
# 17                        0.019683                   0.082789
# 18                        0.013918                   0.056566
# 19                        0.081169                   0.111255
#
#     Saque_Parcelado  Saque_a_Vista  Overlimit
# 0          0.000000       0.000000   0.000000
# 1          0.000149       0.000276   0.078585
# 2          0.001458       0.002500   0.039170
# 3          0.003129       0.002749   0.040228
# 4          0.000005       0.000005   0.000023
# 5          0.002352       0.002332   0.024541
# 6          0.000560       0.001119   0.012350
# 7          0.000000       0.000000   0.000000
# 8          0.000000       0.000000   1.000000
# 9          0.000000       0.000000   0.000000
# 10         0.000000       0.000000   0.585536
# 11         0.370825       0.018671   0.462443
# 12         0.178382       0.793369   0.384670
# 13         0.128728       0.137484   0.538381
# 14         0.036727       0.034603   0.408556
# 15         0.102923       0.092829   0.510674
# 16         0.011570       0.011679   0.101114
# 17         0.017236       0.017970   0.090270
# 18         0.009775       0.010420   0.072965
# 19         0.018485       0.026017   0.142727

# %%
dfTestRes.select("ACCOUNT","prediction").groupBy("prediction").count().orderBy("prediction").toPandas()
# Out:
#     prediction   count
# 0            0  198713
# 1            1  181282
# 2            2  422419
# 3            3  102589
# 4            4  217732
# 5            5  101179
# 6            6   25021
# 7            7  119118
# 8            8  195346
# 9            9   72164
# 10          10   97994
# 11          11   51256
# 12          12   37913
# 13          13   27865
# 14          14   34852
# 15          15   56868
# 16          16   64561
# 17          17   28603
# 18          18   40307
# 19          19   23100

# %% [markdown]
# #### Total

# %%
dfTotal=dfTrainRes.union(dfTestRes)

# %%
dfTotalProdIncl=dfTotal.join(dfTsys,dfTrainRes.ACCOUNT==dfTsys.ACCOUNTPK,'left_outer').fillna(0)

# %%
dfTotalProdIncl.printSchema()
# Out:
# root
#  |-- ACCOUNT: long (nullable = true)
#  |-- prediction: integer (nullable = true)
#  |-- ACCOUNTPK: long (nullable = true)
#  |-- Emprestimo_Pessoal: long (nullable = true)
#  |-- Pagamento_de_Contas: long (nullable = true)
#  |-- Parcelamento_Fatura_Automatico: long (nullable = true)
#  |-- Parcelamento_Fatura_Facil: long (nullable = true)
#  |-- Saque_Parcelado: long (nullable = true)
#  |-- Saque_a_Vista: long (nullable = true)
#  |-- Overlimit: long (nullable = true)

# %%
dfTotalProdIncl.createOrReplaceTempView("tTotalProdIncl")

# %%
dfTotalClusIncl=spark.sql("""SELECT prediction, 
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) Overlimit
    from tTotalProdIncl group by prediction order by prediction""")

# %%
dfTotalClusIncl.toPandas()
# Out:
#     prediction  Emprestimo_Pessoal  Pagamento_de_Contas  \
# 0            0            0.000000             0.000000
# 1            1            0.000083             0.001902
# 2            2            0.000476             0.002839
# 3            3            0.002012             0.003438
# 4            4            0.000056             0.000007
# 5            5            0.001089             0.003506
# 6            6            0.000202             0.001494
# 7            7            0.000000             0.000000
# 8            8            0.000000             0.000000
# 9            9            0.000000             0.000000
# 10          10            0.000000             0.000000
# 11          11            0.001371             0.690123
# 12          12            0.217581             0.100011
# 13          13            0.067837             0.177389
# 14          14            0.007134             0.092935
# 15          15            0.026102             0.105762
# 16          16            0.012838             0.032067
# 17          17            0.000544             0.043961
# 18          18            0.000286             0.023632
# 19          19            0.008886             0.049499
#
#     Parcelamento_Fatura_Automatico  Parcelamento_Fatura_Facil  \
# 0                         0.000000                   0.000000
# 1                         0.013504                   0.034378
# 2                         0.011095                   0.072699
# 3                         0.009478                   0.056823
# 4                         0.000019                   0.000028
# 5                         0.005580                   0.031771
# 6                         0.003171                   0.013289
# 7                         0.000000                   0.641043
# 8                         0.000000                   0.245600
# 9                         1.000000                   0.000000
# 10                        1.000000                   0.588999
# 11                        0.284006                   0.451169
# 12                        0.246606                   0.451986
# 13                        0.433057                   0.363883
# 14                        0.092067                   0.149865
# 15                        0.205860                   0.298602
# 16                        0.083805                   0.174615
# 17                        0.019109                   0.082126
# 18                        0.014455                   0.056541
# 19                        0.081097                   0.111807
#
#     Saque_Parcelado  Saque_a_Vista  Overlimit
# 0          0.000000       0.000000   0.000000
# 1          0.000168       0.000282   0.078701
# 2          0.001523       0.002489   0.038998
# 3          0.003172       0.002828   0.039879
# 4          0.000005       0.000002   0.000019
# 5          0.002268       0.002313   0.024380
# 6          0.000646       0.000969   0.011794
# 7          0.000000       0.000000   0.000000
# 8          0.000000       0.000000   1.000000
# 9          0.000000       0.000000   0.000000
# 10         0.000000       0.000000   0.587890
# 11         0.369285       0.018333   0.461875
# 12         0.178747       0.794981   0.387588
# 13         0.125702       0.135711   0.537243
# 14         0.036034       0.034413   0.408295
# 15         0.104399       0.093499   0.511461
# 16         0.011317       0.010999   0.101297
# 17         0.016597       0.017440   0.090504
# 18         0.009848       0.010494   0.074336
# 19         0.019267       0.026809   0.143015

# %%
dfTotalClusIncl.createOrReplaceTempView("tTotalClusIncl")

# %%
dfOrden=spark.sql("""SELECT prediction,Emprestimo_Pessoal, 
    row_number() over (order by Emprestimo_Pessoal desc) as orden
    from  tTotalClusIncl order by Emprestimo_Pessoal desc""")

# %%
dfOrden.toPandas()
# Out:
#     prediction  Emprestimo_Pessoal  orden
# 0           12            0.217581      1
# 1           13            0.067837      2
# 2           15            0.026102      3
# 3           16            0.012838      4
# 4           19            0.008886      5
# 5           14            0.007134      6
# 6            3            0.002012      7
# 7           11            0.001371      8
# 8            5            0.001089      9
# 9           17            0.000544     10
# 10           2            0.000476     11
# 11          18            0.000286     12
# 12           6            0.000202     13
# 13           1            0.000083     14
# 14           4            0.000056     15
# 15          10            0.000000     16
# 16           0            0.000000     17
# 17           8            0.000000     18
# 18           9            0.000000     19
# 19           7            0.000000     20

# %%
dfTotal.select("ACCOUNT","prediction").groupBy("prediction").count().orderBy("prediction") \
    .withColumn('Percentage', col('count')/dfTotal.count()).toPandas()
# Out:
#     prediction   count  Percentage
# 0            0  396888    0.095251
# 1            1  362183    0.086922
# 2            2  836487    0.200753
# 3            3  203316    0.048795
# 4            4  430248    0.103258
# 5            5  201064    0.048254
# 6            6   49516    0.011884
# 7            7  235485    0.056515
# 8            8  389515    0.093482
# 9            9  142795    0.034270
# 10          10  193800    0.046511
# 11          11  101350    0.024324
# 12          12   74832    0.017959
# 13          13   55353    0.013284
# 14          14   69102    0.016584
# 15          15  112290    0.026949
# 16          16  128918    0.030940
# 17          17   56937    0.013665
# 18          18   80526    0.019326
# 19          19   46142    0.011074

# %%
dfTotalImportanceCluster=spark.sql("""
    SELECT prediction, 
    Emprestimo_Pessoal/AVG_Emprestimo_Pessoal AS Emprestimo_Pessoal, 
    Pagamento_de_Contas/AVG_Pagamento_de_Contas AS Pagamento_de_Contas,
    Parcelamento_Fatura_Automatico/AVG_Parcelamento_Fatura_Automatico AS Parcelamento_Fatura_Automatico,
    Parcelamento_Fatura_Facil/AVG_Parcelamento_Fatura_Facil AS Parcelamento_Fatura_Facil,
    Saque_Parcelado/AVG_Saque_Parcelado  AS Saque_Parcelado,
    Saque_a_Vista/AVG_Saque_a_Vista  AS Saque_a_Vista,
    Overlimit/AVG_Overlimit  AS Overlimit
    FROM
    (SELECT prediction, 
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) Overlimit
    from tTotalProdIncl group by prediction) CLUSTER CROSS JOIN
    (SELECT  
    SUM(CASE WHEN Emprestimo_Pessoal>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Emprestimo_Pessoal,
    SUM(CASE WHEN Pagamento_de_Contas>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Pagamento_de_Contas, 
    SUM(CASE WHEN Parcelamento_Fatura_Automatico>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Parcelamento_Fatura_Automatico, 
    SUM(CASE WHEN Parcelamento_Fatura_Facil>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Parcelamento_Fatura_Facil, 
    SUM(CASE WHEN Saque_Parcelado>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Saque_Parcelado, 
    SUM(CASE WHEN Saque_a_Vista>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Saque_a_Vista,
    SUM(CASE WHEN Overlimit>0 THEN 1 ELSE 0 END)/SUM(1) AVG_Overlimit
    from tTotalProdIncl)
    WHERE 
    order by prediction""")

# %%
dfTotalImportanceCluster.columns[1:]
# Out:
# ['Emprestimo_Pessoal',
#  'Pagamento_de_Contas',
#  'Parcelamento_Fatura_Automatico',
#  'Parcelamento_Fatura_Facil',
#  'Saque_Parcelado',
#  'Saque_a_Vista',
#  'Overlimit']

# %%
cond = "psf.when" + ".when".join(["(psf.col('" + c + "') == psf.col('max_value'), psf.lit('" + c + "'))" for c in dfTotalImportanceCluster.columns[1:]])
import pyspark.sql.functions as psf
dfTotalImportanceCluster.withColumn("max_value", psf.greatest(*dfTotalImportanceCluster.columns[1:]))\
    .withColumn("MAX", eval(cond))\
    .toPandas()
# Out:
#     prediction  Emprestimo_Pessoal  Pagamento_de_Contas  \
# 0            0            0.000000             0.000000
# 1            1            0.012874             0.065556
# 2            2            0.073950             0.097842
# 3            3            0.312657             0.118475
# 4            4            0.008670             0.000240
# 5            5            0.169288             0.120830
# 6            6            0.031389             0.051500
# 7            7            0.000000             0.000000
# 8            8            0.000000             0.000000
# 9            9            0.000000             0.000000
# 10          10            0.000000             0.000000
# 11          11            0.213161            23.781939
# 12          12           33.817143             3.446410
# 13          13           10.543512             6.112891
# 14          14            1.108850             3.202582
# 15          15            4.056872             3.644598
# 16          16            1.995267             1.105039
# 17          17            0.084622             1.514910
# 18          18            0.044392             0.814373
# 19          19            1.381033             1.705769
#
#     Parcelamento_Fatura_Automatico  Parcelamento_Fatura_Facil  \
# 0                         0.000000                   0.000000
# 1                         0.119348                   0.226250
# 2                         0.098058                   0.478456
# 3                         0.083764                   0.373968
# 4                         0.000164                   0.000184
# 5                         0.049318                   0.209094
# 6                         0.028022                   0.087457
# 7                         0.000000                   4.218897
# 8                         0.000000                   1.616370
# 9                         8.837853                   0.000000
# 10                        8.837853                   3.876380
# 11                        2.510002                   2.969281
# 12                        2.179465                   2.974655
# 13                        3.827293                   2.394822
# 14                        0.813673                   0.986309
# 15                        1.819359                   1.965189
# 16                        0.740658                   1.149193
# 17                        0.168881                   0.540495
# 18                        0.127751                   0.372112
# 19                        0.716728                   0.735836
#
#     Saque_Parcelado  Saque_a_Vista  Overlimit  max_value  \
# 0          0.000000       0.000000   0.000000   0.000000
# 1          0.008936       0.013111   0.409819   0.409819
# 2          0.080811       0.115873   0.203073   0.478456
# 3          0.168325       0.131661   0.207662   0.373968
# 4          0.000247       0.000108   0.000097   0.008670
# 5          0.120335       0.107666   0.126956   0.209094
# 6          0.034290       0.045129   0.061416   0.087457
# 7          0.000000       0.000000   0.000000   4.218897
# 8          0.000000       0.000000   5.207321   5.207321
# 9          0.000000       0.000000   0.000000   8.837853
# 10         0.000000       0.000000   3.061330   8.837853
# 11        19.593986       0.853457   2.405130  23.781939
# 12         9.484194      37.009750   2.018296  37.009750
# 13         6.669677       6.317918   2.797595  10.543512
# 14         1.911922       1.602067   2.126123   3.202582
# 15         5.539355       4.352777   2.663343   5.539355
# 16         0.600487       0.512062   0.527486   1.995267
# 17         0.880641       0.811922   0.471281   1.514910
# 18         0.522515       0.488517   0.387093   0.814373
# 19         1.022273       1.248052   0.744725   1.705769
#
#                                MAX
# 0               Emprestimo_Pessoal
# 1                        Overlimit
# 2        Parcelamento_Fatura_Facil
# 3        Parcelamento_Fatura_Facil
# 4               Emprestimo_Pessoal
# 5        Parcelamento_Fatura_Facil
# 6        Parcelamento_Fatura_Facil
# 7        Parcelamento_Fatura_Facil
# 8                        Overlimit
# 9   Parcelamento_Fatura_Automatico
# 10  Parcelamento_Fatura_Automatico
# 11             Pagamento_de_Contas
# 12                   Saque_a_Vista
# 13              Emprestimo_Pessoal
# 14             Pagamento_de_Contas
# 15                 Saque_Parcelado
# 16              Emprestimo_Pessoal
# 17             Pagamento_de_Contas
# 18             Pagamento_de_Contas
# 19             Pagamento_de_Contas

# %% [markdown]
# ### Cluster Analysis

# %% [markdown]
# #### Products

# %%
#dfAnalysis=spark.read.parquet("/analytics/bc1_clustering/tables/dfAnalysisBin")
dfAnalysis=spark.read.parquet("/analytics/bc1_clustering/tables/dfAnalysis11Dic")

# %%
dfAnalysis.printSchema()
# Out:
# root
#  |-- ACCOUNTPK: long (nullable = true)
#  |-- PRF_DS_DEPARTAMENTO: string (nullable = true)
#  |-- PRF_DS_SETOR: string (nullable = true)
#  |-- PURCHASES: double (nullable = true)

# %%
dfAnTmp1=dfAnalysis.join(dfTrainRes,dfTrainRes.ACCOUNT==dfAnalysis.ACCOUNTPK)

# %%
dfAnTmp1.printSchema()
# Out:
# root
#  |-- ACCOUNTPK: long (nullable = true)
#  |-- PRF_DS_DEPARTAMENTO: string (nullable = true)
#  |-- PRF_DS_SETOR: string (nullable = true)
#  |-- PURCHASES: double (nullable = true)
#  |-- ACCOUNT: long (nullable = true)
#  |-- prediction: integer (nullable = true)

# %%
dfAnTmp1.createOrReplaceTempView('tdfAnTmp1')

# %%
dfSectorImportance=spark.sql("""SELECT * FROM (
    SELECT prediction, SECTOR, IMPORTANCE, 
    row_number() over (partition by prediction order by IMPORTANCE desc) as orden FROM 
    (
    SELECT prediction, SECTOR, AVGPRED/AVGTOTAL AS IMPORTANCE FROM 
    (SELECT PRF_DS_SETOR as SECTOR, SUM(PURCHASES)/COUNT(DISTINCT ACCOUNT) AS AVGTOTAL
    FROM tdfAnTmp1 GROUP BY PRF_DS_SETOR ORDER BY SECTOR) A,
    (SELECT prediction, PRF_DS_SETOR as SECTORPRED, SUM(PURCHASES)/COUNT(DISTINCT ACCOUNT) AS AVGPRED
    FROM tdfAnTmp1 GROUP BY prediction, PRF_DS_SETOR ORDER BY SECTORPRED) B
    WHERE SECTOR=SECTORPRED ORDER BY prediction, SECTOR) MAIN
    ORDER BY prediction, orden) FINAL
    WHERE orden=1""")
dfSectorImportance.printSchema()
# Out:
# root
#  |-- prediction: integer (nullable = true)
#  |-- SECTOR: string (nullable = true)
#  |-- IMPORTANCE: double (nullable = true)
#  |-- orden: integer (nullable = true)

# %%
dfSectorImportance.toPandas()
# Out:
#     prediction                   SECTOR  IMPORTANCE  orden
# 0            0  FERRAMENTAS AUTOMOTIVOS    1.324788      1
# 1            1                HI-FI SOM    0.966116      1
# 2            2        SERVICOS DIGITAIS    1.460378      1
# 3            3           VENDAS PAPELAO    3.465537      1
# 4            4               VASILHAMES    1.440543      1
# 5            5                  SACOLAS    1.135237      1
# 6            6                     SECA    5.420191      1
# 7            7               VASILHAMES    2.348474      1
# 8            8               VASILHAMES    1.276361      1
# 9            9                 DROGARIA    1.171146      1
# 10          10               VASILHAMES    1.513135      1
# 11          11                     BEBE    1.050661      1
# 12          12               VASILHAMES    2.401761      1
# 13          13                  LIQUIDA    2.857728      1
# 14          14                     CASA    2.580768      1
# 15          15         POSTO E SERVICOS    1.513794      1
# 16          16         POSTO E SERVICOS    1.591306      1
# 17          17         POSTO E SERVICOS    1.863041      1
# 18          18         POSTO E SERVICOS    1.577693      1
# 19          19                     SECA    8.316879      1

# %% [markdown]
# #### Demographic

# %%
#LECTURA DE TABLA PARQUET
dfPeople=spark.read.parquet("/analytics/bc1_clustering/tables/dfPeople")
dfPeople=dfPeople.withColumnRenamed("SERNO","PEOPLESERNO").withColumn('YOB',(dfPeople["DOB"]/10000).cast('integer'))
dfAccounts=spark.read.parquet("/analytics/bc1_clustering/tables/dfAccountsRefdate")
dfAccounts=dfAccounts.withColumnRenamed("SERNO","ACCOUNTSERNO").withColumnRenamed("PEOPLESERNO","PEOPLESERNOFK")

# %%
dfDemographic=dfTrainRes.join(dfAccounts,dfAccounts.ACCOUNTSERNO==dfTrainRes.ACCOUNT) \
    .join(dfPeople,dfPeople.PEOPLESERNO==dfAccounts.PEOPLESERNOFK) \
    .select('ACCOUNTSERNO','prediction','PEOPLESERNO','SEX','MARITAL_STATUS','YOB').persist()

# %%
dfDemographic.createOrReplaceTempView("tDemographic")

# %%
dfAge=spark.sql("""SELECT prediction, round(AVG(YOB),0) as cuenta from tDemographic group by prediction order by prediction""")
dfAge.toPandas()
# Out:
#     prediction  cuenta
# 0            0  1972.0
# 1            1  1970.0
# 2            2  1971.0
# 3            3  1965.0
# 4            4  1968.0
# 5            5  1962.0
# 6            6  1964.0
# 7            7  1972.0
# 8            8  1971.0
# 9            9  1968.0
# 10          10  1968.0
# 11          11  1967.0
# 12          12  1966.0
# 13          13  1965.0
# 14          14  1962.0
# 15          15  1966.0
# 16          16  1966.0
# 17          17  1956.0
# 18          18  1956.0
# 19          19  1958.0

# %%
dfSex=spark.sql("""SELECT A.*, B.total, round(cuenta/total,2) as porcentaje FROM 
    (SELECT prediction, SEX, COUNT(*) as cuenta from tDemographic group by prediction, SEX) A,
    (SELECT prediction, COUNT(*) as total from tDemographic group by prediction) B
    WHERE A.prediction=B.prediction order by prediction, SEX""")
dfSex.toPandas()
# Out:
#     prediction SEX  cuenta   total  porcentaje
# 0            0   F  106145  198175        0.54
# 1            0   M   92030  198175        0.46
# 2            1   F   95816  180901        0.53
# 3            1   M   85085  180901        0.47
# 4            2   F  230642  414068        0.56
# 5            2   M  183426  414068        0.44
# 6            3   F   49473  100727        0.49
# 7            3   M   51254  100727        0.51
# 8            4   F  147299  212516        0.69
# 9            4   M   65216  212516        0.31
# 10           4   U       1  212516        0.00
# 11           5   F   56223   99885        0.56
# 12           5   M   43662   99885        0.44
# 13           6   F   14236   24495        0.58
# 14           6   M   10259   24495        0.42
# 15           7   F   81253  116367        0.70
# 16           7   M   35114  116367        0.30
# 17           8   F  131047  194169        0.67
# 18           8   M   63122  194169        0.33
# 19           9   F   48158   70631        0.68
# 20           9   M   22473   70631        0.32
# 21          10   F   69483   95806        0.73
# 22          10   M   26323   95806        0.27
# 23          11   F   36218   50094        0.72
# 24          11   M   13876   50094        0.28
# 25          12   F   27443   36919        0.74
# 26          12   M    9476   36919        0.26
# 27          13   F   19514   27488        0.71
# 28          13   M    7974   27488        0.29
# 29          14   F   24642   34250        0.72
# 30          14   M    9608   34250        0.28
# 31          15   F   39769   55421        0.72
# 32          15   M   15652   55421        0.28
# 33          16   F   40595   64357        0.63
# 34          16   M   23762   64357        0.37
# 35          17   F   17789   28334        0.63
# 36          17   M   10545   28334        0.37
# 37          18   F   24120   40219        0.60
# 38          18   M   16099   40219        0.40
# 39          19   F   13992   23042        0.61
# 40          19   M    9050   23042        0.39

# %%
dfMarital=spark.sql("""SELECT A.*, B.total, round(cuenta/total,2) as porcentaje FROM 
    (SELECT prediction, MARITAL_STATUS, COUNT(*) as cuenta from tDemographic group by prediction, MARITAL_STATUS) A,
    (SELECT prediction, COUNT(*) as total from tDemographic group by prediction) B
    WHERE A.prediction=B.prediction order by prediction, MARITAL_STATUS""")
dfMarital.toPandas()
# Out:
#      prediction MARITAL_STATUS  cuenta   total  porcentaje
# 0             0              C   31521  198175        0.16
# 1             0              D   10962  198175        0.06
# 2             0              M   89259  198175        0.45
# 3             0              O   18471  198175        0.09
# 4             0              S   38996  198175        0.20
# 5             0              W    8966  198175        0.05
# 6             1              C   21915  180901        0.12
# 7             1              D   11420  180901        0.06
# 8             1              M   89108  180901        0.49
# 9             1              O   15436  180901        0.09
# 10            1              S   35540  180901        0.20
# 11            1              W    7482  180901        0.04
# 12            2                    108  414068        0.00
# 13            2              C   33172  414068        0.08
# 14            2              D   19562  414068        0.05
# 15            2              M  188333  414068        0.45
# 16            2              O   44308  414068        0.11
# 17            2              S  111047  414068        0.27
# 18            2              W   17538  414068        0.04
# 19            3                     55  100727        0.00
# 20            3              C    4825  100727        0.05
# 21            3              D    5320  100727        0.05
# 22            3              M   58131  100727        0.58
# 23            3              O    9851  100727        0.10
# 24            3              S   18031  100727        0.18
# 25            3              W    4514  100727        0.04
# 26            4              C   19869  212516        0.09
# 27            4              D    8885  212516        0.04
# 28            4              M   69959  212516        0.33
# 29            4              O   76083  212516        0.36
# ..          ...            ...     ...     ...         ...
# 94           15              C    2231   55421        0.04
# 95           15              D    1510   55421        0.03
# 96           15              M   16588   55421        0.30
# 97           15              O   27584   55421        0.50
# 98           15              S    5400   55421        0.10
# 99           15              W    2108   55421        0.04
# 100          16              C    1851   64357        0.03
# 101          16              D    1446   64357        0.02
# 102          16              M   24343   64357        0.38
# 103          16              O   27367   64357        0.43
# 104          16              S    6976   64357        0.11
# 105          16              W    2374   64357        0.04
# 106          17              C     390   28334        0.01
# 107          17              D     573   28334        0.02
# 108          17              M   12440   28334        0.44
# 109          17              O   11959   28334        0.42
# 110          17              S    1725   28334        0.06
# 111          17              W    1247   28334        0.04
# 112          18              C     697   40219        0.02
# 113          18              D    1037   40219        0.03
# 114          18              M   18955   40219        0.47
# 115          18              O   14578   40219        0.36
# 116          18              S    2890   40219        0.07
# 117          18              W    2062   40219        0.05
# 118          19              C     559   23042        0.02
# 119          19              D     600   23042        0.03
# 120          19              M   10943   23042        0.47
# 121          19              O    7892   23042        0.34
# 122          19              S    1941   23042        0.08
# 123          19              W    1107   23042        0.05
#
# [124 rows x 5 columns]

# %% [markdown]
# ### Model saving

# %%
#Iter2 -> grupo, part, dinero, 6*IQR

# %%
model.save("/analytics/bc1_clustering/models/model2DicGrp")

# %%
sparkFeaturePipelineModel.save("/analytics/bc1_clustering/models/pipeline12DicGrp")

# %%
transformer.save("/analytics/bc1_clustering/models/scaleFinancial12DicGrp")

# %%
dfOrden.write.parquet("/analytics/bc1_clustering/tables/dfOrden12DicGrp")

# %%
# sparkFeaturePipelineModel=PipelineModel.load("/analytics/bc1_clustering/models/pipelineOriginal")

# %%
# model=BisectingKMeansModel.load("/analytics/bc1_clustering/models/modelOriginal")
